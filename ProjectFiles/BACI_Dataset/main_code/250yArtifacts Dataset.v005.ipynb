# %%
# TO DO: 
# Convert the network into a bipartite/pseudo-bipartite network, between importers on one side and exporters on the other
# Already doing this we would have done a lot of network analysis and shown off a lot
# Then also include a previous years' network and we can do a comparison between the two

# %%
from collections import defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import os
from networkx.algorithms import bipartite as bpt

import glob

# %%
# Point to the 2022 BACI csv dataset for Mac
#file_path = "/Users/zenrehda/Desktop/NAProject/BACI_HS22_Y2022_V202401b.csv"
#file_path_countries = "/Users/zenrehda/Desktop/NAProject/country_codes_V202401b.csv"

# %%
# Point to the 2022 BACI csv dataset for windows
file_path = "BACI_HS22_Y2022_V202401b.csv"
file_path_countries = "country_codes_V202401b.csv"

# %%
# Our product code for historical artifacts, saved as a list if we want to include multiple product codes
product_codes = [970610]

# %%
# Read the CSV in chunks, ensuring the Multi-Index structure is preserved
filtered_data = pd.concat(
    chunk[chunk.index.get_level_values('k').isin(product_codes)] for chunk in pd.read_csv(
        file_path, chunksize=10000, index_col=[0, 1, 2, 3, 4, 5]  # Adjust this list to match your Multi-Index levels
    )
)

# %%
# Out:
# Nodes in the graph: 252
# Edges in the graph: 1904

# %%
# Read the CSV in chunks, ensuring the Multi-Index structure is preserved
filtered_countries = pd.concat(
    chunk for chunk in pd.read_csv(
        file_path_countries, chunksize=10000, index_col=[0, 1, 2, 3]  # Adjust this list to match your Multi-Index levels
    )
)

# %% [markdown]
# ### The codes for each index:
# 't' = year
#
# 'i' = exporter
#
# 'j' = importer
#
# 'k' = product
#
# 'v' = value
#
# 'q' = quantity

# %%
# DO NOT RUN YET - Code is created to work on a MultiIndex, so we have 0 columns. If we want columns, reset index below

# We reset the index to make sure the columns work as intended, as pandas currently treats this as a MultiIndex (complicado, no me gusta)
#filtered_data = filtered_data.reset_index()

# This will give us the clearly defined columns
#print(filtered_data.columns)

# %%
filtered_data
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2022, 4, 276, 970610, 1.759,         0.003), (2022, 4, 372, 970610, 36.632,         0.015), (2022, 4, 826, 970610, 33.359,         0.034), (2022, 4, 842, 970610, 3.823,         0.002), (2022, 8, 757, 970610, 2.589,         0.013), (2022, 12, 757, 970610, 14.555,         0.004), (2022, 24, 842, 970610, 367.979,         0.029), (2022, 31, 826, 970610, 24.165,         0.012), (2022, 31, 842, 970610, 214.325,         0.065), (2022, 32, 251, 970610, 3.313,         0.002), (2022, 32, 348, 970610, 0.192,            NA), (2022, 32, 842, 970610, 159.839,        40.315), (2022, 36, 246, 970610, 8.567,         0.002), (2022, 36, 276, 970610, 2.984,         0.002), (2022, 36, 372, 970610, 11.188,         0.004), (2022, 36, 380, 970610, 6.303,         0.014), (2022, 36, 528, 970610, 1.391,         0.022), (2022, 36, 554, 970610, 22.597,            NA), (2022, 36, 757, 970610, 1.732,         0.003), (2022, 36, 826, 970610, 519.759,         0.988), (2022, 36, 842, 970610, 46.462,         0.049), (2022, 40, 32, 970610, 8.951,         0.250), (2022, 40, 36, 970610, 62.233,         0.088), (2022, 40, 56, 970610, 2.92,         0.011), (2022, 40, 100, 970610, 0.398,         0.001), (2022, 40, 124, 970610, 72.395,         0.021), (2022, 40, 156, 970610, 233.325,         0.094), (2022, 40, 191, 970610, 1.885,         0.006), (2022, 40, 196, 970610, 1.237,         0.004), (2022, 40, 203, 970610, 7.702,         0.018), (2022, 40, 208, 970610, 1.531,         0.001), (2022, 40, 233, 970610, 0.31,         0.002), (2022, 40, 246, 970610, 0.2,         0.001), (2022, 40, 251, 970610, 125.54,         0.169), (2022, 40, 276, 970610, 83.202,         0.078), (2022, 40, 300, 970610, 1.869,         0.005), (2022, 40, 344, 970610, 1143.926,         1.112), (2022, 40, 348, 970610, 13.871,         0.026), (2022, 40, 372, 970610, 4.08,         0.011), (2022, 40, 376, 970610, 56.432,         0.002), (2022, 40, 380, 970610, 36.132,         0.045), (2022, 40, 392, 970610, 254.361,         0.031), (2022, 40, 410, 970610, 1.028,         0.004), (2022, 40, 440, 970610, 0.164,         0.001), (2022, 40, 442, 970610, 0.269,         0.001), (2022, 40, 490, 970610, 231.12,         0.066), (2022, 40, 528, 970610, 13.628,         0.022), (2022, 40, 579, 970610, 0.776,         0.009), (2022, 40, 616, 970610, 5.542,         0.020), (2022, 40, 620, 970610, 3.874,         0.011), (2022, 40, 642, 970610, 2.847,         0.011), (2022, 40, 643, 970610, 8.62,         0.006), (2022, 40, 699, 970610, 34.536,         0.095), (2022, 40, 703, 970610, 1.873,         0.008), (2022, 40, 705, 970610, 3.686,         0.004), (2022, 40, 724, 970610, 6.31,         0.018), (2022, 40, 752, 970610, 0.805,         0.003), (2022, 40, 757, 970610, 444.043,         0.719), (2022, 40, 792, 970610, 4.16,         0.001), (2022, 40, 826, 970610, 828.397,         0.351), (2022, 40, 842, 970610, 1571.229,         4.307), (2022, 48, 826, 970610, 3.817,         0.001), (2022, 51, 757, 970610, 31.668,         0.009), (2022, 51, 826, 970610, 362.431,         0.001), (2022, 56, 36, 970610, 146.088,         0.086), (2022, 56, 40, 970610, 3.159,         0.002), (2022, 56, 124, 970610, 39.857,         0.158), (2022, 56, 136, 970610, 1.895,         0.004), (2022, 56, 152, 970610, 0.181,         0.002), (2022, 56, 156, 970610, 1.363,         0.002), (2022, 56, 251, 970610, 506.858,         0.711), (2022, 56, 276, 970610, 129.552,         0.112), (2022, 56, 344, 970610, 105.425,         0.060), (2022, 56, 376, 970610, 48.595,         0.428), (2022, 56, 380, 970610, 80.096,         0.001), (2022, 56, 392, 970610, 49.251,         0.006), (2022, 56, 410, 970610, 11.427,         0.012), (2022, 56, 442, 970610, 0.16,         0.012), (2022, 56, 484, 970610, 2.582,         0.003), (2022, 56, 490, 970610, 3.218,         0.004), (2022, 56, 528, 970610, 3.834,         0.008), (2022, 56, 554, 970610, 1.264,         0.001), (2022, 56, 579, 970610, 1.085,         0.001), (2022, 56, 634, 970610, 24.747,         0.900), (2022,  ...
#
# [952 rows x 0 columns]

# %%
filtered_countries
# Out:
# Empty DataFrame
# Columns: []
# Index: [(4, Afghanistan, AF, AFG), (8, Albania, AL, ALB), (12, Algeria, DZ, DZA), (16, American Samoa, AS, ASM), (20, Andorra, AD, AND), (24, Angola, AO, AGO), (28, Antigua and Barbuda, AG, ATG), (31, Azerbaijan, AZ, AZE), (32, Argentina, AR, ARG), (36, Australia, AU, AUS), (40, Austria, AT, AUT), (44, Bahamas, BS, BHS), (48, Bahrain, BH, BHR), (50, Bangladesh, BD, BGD), (51, Armenia, AM, ARM), (52, Barbados, BB, BRB), (56, Belgium, BE, BEL), (58, Belgium-Luxembourg (...1998), BE, BEL), (60, Bermuda, BM, BMU), (64, Bhutan, BT, BTN), (68, Bolivia (Plurinational State of), BO, BOL), (70, Bosnia Herzegovina, BA, BIH), (72, Botswana, BW, BWA), (76, Brazil, BR, BRA), (84, Belize, BZ, BLZ), (86, Br. Indian Ocean Terr., IO, IOT), (90, Solomon Isds, SB, SLB), (92, Br. Virgin Isds, VG, VGB), (96, Brunei Darussalam, BN, BRN), (100, Bulgaria, BG, BGR), (104, Myanmar, MM, MMR), (108, Burundi, BI, BDI), (112, Belarus, BY, BLR), (116, Cambodia, KH, KHM), (120, Cameroon, CM, CMR), (124, Canada, CA, CAN), (132, Cabo Verde, CV, CPV), (136, Cayman Isds, KY, CYM), (140, Central African Rep., CF, CAF), (144, Sri Lanka, LK, LKA), (148, Chad, TD, TCD), (152, Chile, CL, CHL), (156, China, CN, CHN), (162, Christmas Isds, CX, CXR), (166, Cocos Isds, CC, CCK), (170, Colombia, CO, COL), (174, Comoros, KM, COM), (175, Mayotte (Overseas France), YT, MYT), (178, Congo, CG, COG), (180, Dem. Rep. of the Congo, CD, COD), (184, Cook Isds, CK, COK), (188, Costa Rica, CR, CRI), (191, Croatia, HR, HRV), (192, Cuba, CU, CUB), (196, Cyprus, CY, CYP), (200, Czechoslovakia (...1992), CS, CSK), (203, Czechia, CZ, CZE), (204, Benin, BJ, BEN), (208, Denmark, DK, DNK), (212, Dominica, DM, DMA), (214, Dominican Rep., DO, DOM), (218, Ecuador, EC, ECU), (222, El Salvador, SV, SLV), (226, Equatorial Guinea, GQ, GNQ), (231, Ethiopia, ET, ETH), (232, Eritrea, ER, ERI), (233, Estonia, EE, EST), (238, Falkland Isds (Malvinas), FK, FLK), (242, Fiji, FJ, FJI), (246, Finland, FI, FIN), (251, France, FR, FRA), (258, French Polynesia, PF, PYF), (260, Fr. South Antarctic Terr., TF, ATF), (262, Djibouti, DJ, DJI), (266, Gabon, GA, GAB), (268, Georgia, GE, GEO), (270, Gambia, GM, GMB), (275, State of Palestine, PS, PSE), (276, Germany, DE, DEU), (278, Dem. Rep. of Germany (...1990), DD, DDR), (280, Fed. Rep. of Germany (...1990), DE, DEU), (288, Ghana, GH, GHA), (292, Gibraltar, GI, GIB), (296, Kiribati, KI, KIR), (300, Greece, GR, GRC), (304, Greenland, GL, GRL), (308, Grenada, GD, GRD), (316, Guam, GU, GUM), (320, Guatemala, GT, GTM), (324, Guinea, GN, GIN), (328, Guyana, GY, GUY), (332, Haiti, HT, HTI), (340, Honduras, HN, HND), (344, China, Hong Kong SAR, HK, HKG), (348, Hungary, HU, HUN), (352, Iceland, IS, ISL), (360, Indonesia, ID, IDN), (364, Iran, IR, IRN), (368, Iraq, IQ, IRQ), (372, Ireland, IE, IRL), ...]
#
# [238 rows x 0 columns]

# %%
# Reset index to convert MultiIndex into columns
filtered_countries = filtered_countries.reset_index()

# Check structure after reset
print(filtered_countries.columns)
# Out:
# Index(['country_code', 'country_name', 'country_iso2', 'country_iso3'], dtype='object')

# %%
# Create the mapping from 'country_code' to 'country_name'
code_to_name = filtered_countries.set_index('country_code')['country_name'].to_dict()

# Replace the levels in filtered_data
filtered_data.index = filtered_data.index.set_levels(
    filtered_data.index.levels[1].map(code_to_name), level='i'
).set_levels(
    filtered_data.index.levels[2].map(code_to_name), level='j'
)

# Display the updated data
print(filtered_data.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2022, Afghanistan, Germany, 970610, 1.759,         0.003), (2022, Afghanistan, Ireland, 970610, 36.632,         0.015), (2022, Afghanistan, United Kingdom, 970610, 33.359,         0.034), (2022, Afghanistan, USA, 970610, 3.823,         0.002), (2022, Albania, Switzerland, 970610, 2.589,         0.013)]

# %%
filtered_data
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2022, Afghanistan, Germany, 970610, 1.759,         0.003), (2022, Afghanistan, Ireland, 970610, 36.632,         0.015), (2022, Afghanistan, United Kingdom, 970610, 33.359,         0.034), (2022, Afghanistan, USA, 970610, 3.823,         0.002), (2022, Albania, Switzerland, 970610, 2.589,         0.013), (2022, Algeria, Switzerland, 970610, 14.555,         0.004), (2022, Angola, USA, 970610, 367.979,         0.029), (2022, Azerbaijan, United Kingdom, 970610, 24.165,         0.012), (2022, Azerbaijan, USA, 970610, 214.325,         0.065), (2022, Argentina, France, 970610, 3.313,         0.002), (2022, Argentina, Hungary, 970610, 0.192,            NA), (2022, Argentina, USA, 970610, 159.839,        40.315), (2022, Australia, Finland, 970610, 8.567,         0.002), (2022, Australia, Germany, 970610, 2.984,         0.002), (2022, Australia, Ireland, 970610, 11.188,         0.004), (2022, Australia, Italy, 970610, 6.303,         0.014), (2022, Australia, Netherlands, 970610, 1.391,         0.022), (2022, Australia, New Zealand, 970610, 22.597,            NA), (2022, Australia, Switzerland, 970610, 1.732,         0.003), (2022, Australia, United Kingdom, 970610, 519.759,         0.988), (2022, Australia, USA, 970610, 46.462,         0.049), (2022, Austria, Argentina, 970610, 8.951,         0.250), (2022, Austria, Australia, 970610, 62.233,         0.088), (2022, Austria, Belgium, 970610, 2.92,         0.011), (2022, Austria, Bulgaria, 970610, 0.398,         0.001), (2022, Austria, Canada, 970610, 72.395,         0.021), (2022, Austria, China, 970610, 233.325,         0.094), (2022, Austria, Croatia, 970610, 1.885,         0.006), (2022, Austria, Cyprus, 970610, 1.237,         0.004), (2022, Austria, Czechia, 970610, 7.702,         0.018), (2022, Austria, Denmark, 970610, 1.531,         0.001), (2022, Austria, Estonia, 970610, 0.31,         0.002), (2022, Austria, Finland, 970610, 0.2,         0.001), (2022, Austria, France, 970610, 125.54,         0.169), (2022, Austria, Germany, 970610, 83.202,         0.078), (2022, Austria, Greece, 970610, 1.869,         0.005), (2022, Austria, China, Hong Kong SAR, 970610, 1143.926,         1.112), (2022, Austria, Hungary, 970610, 13.871,         0.026), (2022, Austria, Ireland, 970610, 4.08,         0.011), (2022, Austria, Israel, 970610, 56.432,         0.002), (2022, Austria, Italy, 970610, 36.132,         0.045), (2022, Austria, Japan, 970610, 254.361,         0.031), (2022, Austria, Rep. of Korea, 970610, 1.028,         0.004), (2022, Austria, Lithuania, 970610, 0.164,         0.001), (2022, Austria, Luxembourg, 970610, 0.269,         0.001), (2022, Austria, Other Asia, nes, 970610, 231.12,         0.066), (2022, Austria, Netherlands, 970610, 13.628,         0.022), (2022, Austria, Norway, 970610, 0.776,         0.009), (2022, Austria, Poland, 970610, 5.542,         0.020), (2022, Austria, Portugal, 970610, 3.874,         0.011), (2022, Austria, Romania, 970610, 2.847,         0.011), (2022, Austria, Russian Federation, 970610, 8.62,         0.006), (2022, Austria, India, 970610, 34.536,         0.095), (2022, Austria, Slovakia, 970610, 1.873,         0.008), (2022, Austria, Slovenia, 970610, 3.686,         0.004), (2022, Austria, Spain, 970610, 6.31,         0.018), (2022, Austria, Sweden, 970610, 0.805,         0.003), (2022, Austria, Switzerland, 970610, 444.043,         0.719), (2022, Austria, Türkiye, 970610, 4.16,         0.001), (2022, Austria, United Kingdom, 970610, 828.397,         0.351), (2022, Austria, USA, 970610, 1571.229,         4.307), (2022, Bahrain, United Kingdom, 970610, 3.817,         0.001), (2022, Armenia, Switzerland, 970610, 31.668,         0.009), (2022, Armenia, United Kingdom, 970610, 362.431,         0.001), (2022, Belgium, Australia, 970610, 146.088,         0.086), (2022, Belgium, Austria, 970610, 3.159,         0.002), (2022, Belgium, Canada, 970610, 39.857,         0.158), (2022, Belgium, Cayman Isds, 970610, 1.895,         0.004), (2022, Belgium, C ...
#
# [952 rows x 0 columns]

# %%
# Create a dictionary to hold DataFrames for each unique `i`
datasets_by_exporter = {exporter: data for exporter, data in filtered_data.groupby(level='i')}


# Optionally, you can save each DataFrame to a CSV file if needed
for exporter, df in datasets_by_exporter.items():
    output_file = f"export_csv/dataset_for_exporter_{exporter}.csv"  # Modify the filename as needed
    df.to_csv(output_file)  # Save to CSV
    print(f"Saved dataset for exporter {exporter} to {output_file}")
# Out:
# Saved dataset for exporter Afghanistan to export_csv/dataset_for_exporter_Afghanistan.csv
# Saved dataset for exporter Albania to export_csv/dataset_for_exporter_Albania.csv
# Saved dataset for exporter Algeria to export_csv/dataset_for_exporter_Algeria.csv
# Saved dataset for exporter Angola to export_csv/dataset_for_exporter_Angola.csv
# Saved dataset for exporter Argentina to export_csv/dataset_for_exporter_Argentina.csv
# Saved dataset for exporter Armenia to export_csv/dataset_for_exporter_Armenia.csv
# Saved dataset for exporter Australia to export_csv/dataset_for_exporter_Australia.csv
# Saved dataset for exporter Austria to export_csv/dataset_for_exporter_Austria.csv
# Saved dataset for exporter Azerbaijan to export_csv/dataset_for_exporter_Azerbaijan.csv
# Saved dataset for exporter Bahrain to export_csv/dataset_for_exporter_Bahrain.csv
# Saved dataset for exporter Belgium to export_csv/dataset_for_exporter_Belgium.csv
# Saved dataset for exporter Bolivia (Plurinational State of) to export_csv/dataset_for_exporter_Bolivia (Plurinational State of).csv
# Saved dataset for exporter Brazil to export_csv/dataset_for_exporter_Brazil.csv
# Saved dataset for exporter Bulgaria to export_csv/dataset_for_exporter_Bulgaria.csv
# Saved dataset for exporter Cambodia to export_csv/dataset_for_exporter_Cambodia.csv
# Saved dataset for exporter Cameroon to export_csv/dataset_for_exporter_Cameroon.csv
# Saved dataset for exporter Canada to export_csv/dataset_for_exporter_Canada.csv
# Saved dataset for exporter Chile to export_csv/dataset_for_exporter_Chile.csv
# Saved dataset for exporter China to export_csv/dataset_for_exporter_China.csv
# Saved dataset for exporter China, Hong Kong SAR to export_csv/dataset_for_exporter_China, Hong Kong SAR.csv
# Saved dataset for exporter Colombia to export_csv/dataset_for_exporter_Colombia.csv
# Saved dataset for exporter Costa Rica to export_csv/dataset_for_exporter_Costa Rica.csv
# Saved dataset for exporter Croatia to export_csv/dataset_for_exporter_Croatia.csv
# Saved dataset for exporter Cyprus to export_csv/dataset_for_exporter_Cyprus.csv
# Saved dataset for exporter Czechia to export_csv/dataset_for_exporter_Czechia.csv
# Saved dataset for exporter Dem. Rep. of the Congo to export_csv/dataset_for_exporter_Dem. Rep. of the Congo.csv
# Saved dataset for exporter Denmark to export_csv/dataset_for_exporter_Denmark.csv
# Saved dataset for exporter Dominican Rep. to export_csv/dataset_for_exporter_Dominican Rep..csv
# Saved dataset for exporter Egypt to export_csv/dataset_for_exporter_Egypt.csv
# Saved dataset for exporter Estonia to export_csv/dataset_for_exporter_Estonia.csv
# Saved dataset for exporter Ethiopia to export_csv/dataset_for_exporter_Ethiopia.csv
# Saved dataset for exporter Finland to export_csv/dataset_for_exporter_Finland.csv
# Saved dataset for exporter France to export_csv/dataset_for_exporter_France.csv
# Saved dataset for exporter French Polynesia to export_csv/dataset_for_exporter_French Polynesia.csv
# Saved dataset for exporter Georgia to export_csv/dataset_for_exporter_Georgia.csv
# Saved dataset for exporter Germany to export_csv/dataset_for_exporter_Germany.csv
# Saved dataset for exporter Greece to export_csv/dataset_for_exporter_Greece.csv
# Saved dataset for exporter Guatemala to export_csv/dataset_for_exporter_Guatemala.csv
# Saved dataset for exporter Hungary to export_csv/dataset_for_exporter_Hungary.csv
# Saved dataset for exporter India to export_csv/dataset_for_exporter_India.csv
# Saved dataset for exporter Indonesia to export_csv/dataset_for_exporter_Indonesia.csv
# Saved dataset for exporter Iran to export_csv/dataset_for_exporter_Iran.csv
# Saved dataset for exporter Iraq to export_csv/dataset_for_exporter_Iraq.csv
# Saved dataset for exporter Ireland to export_csv/dataset_for_exporter_Ireland.csv
# Saved dataset for exporter Israel to export_csv/dataset_for_exporter_Israel.csv
# Saved dataset for exporter Italy to export_csv/dataset_for_exporter_Italy.csv
# Saved dataset for exporter Jamaica to export_csv/dataset_for_exporter_Jamaica.csv
# Saved dataset for exporter Japan to export_csv/dataset_for_exporter_Japan.csv
# Saved dataset for exporter Jordan to export_csv/dataset_for_exporter_Jordan.csv
# Saved dataset for exporter Kenya to export_csv/dataset_for_exporter_Kenya.csv
# Saved dataset for exporter Lao People's Dem. Rep. to export_csv/dataset_for_exporter_Lao People's Dem. Rep..csv
# Saved dataset for exporter Latvia to export_csv/dataset_for_exporter_Latvia.csv
# Saved dataset for exporter Lebanon to export_csv/dataset_for_exporter_Lebanon.csv
# Saved dataset for exporter Libya to export_csv/dataset_for_exporter_Libya.csv
# Saved dataset for exporter Lithuania to export_csv/dataset_for_exporter_Lithuania.csv
# Saved dataset for exporter Luxembourg to export_csv/dataset_for_exporter_Luxembourg.csv
# Saved dataset for exporter Madagascar to export_csv/dataset_for_exporter_Madagascar.csv
# Saved dataset for exporter Mali to export_csv/dataset_for_exporter_Mali.csv
# Saved dataset for exporter Malta to export_csv/dataset_for_exporter_Malta.csv
# Saved dataset for exporter Mexico to export_csv/dataset_for_exporter_Mexico.csv
# Saved dataset for exporter Morocco to export_csv/dataset_for_exporter_Morocco.csv
# Saved dataset for exporter Myanmar to export_csv/dataset_for_exporter_Myanmar.csv
# Saved dataset for exporter Namibia to export_csv/dataset_for_exporter_Namibia.csv
# Saved dataset for exporter Nepal to export_csv/dataset_for_exporter_Nepal.csv
# Saved dataset for exporter Netherlands to export_csv/dataset_for_exporter_Netherlands.csv
# Saved dataset for exporter New Zealand to export_csv/dataset_for_exporter_New Zealand.csv
# Saved dataset for exporter Niger to export_csv/dataset_for_exporter_Niger.csv
# Saved dataset for exporter Nigeria to export_csv/dataset_for_exporter_Nigeria.csv
# Saved dataset for exporter Norway to export_csv/dataset_for_exporter_Norway.csv
# Saved dataset for exporter Oman to export_csv/dataset_for_exporter_Oman.csv
# Saved dataset for exporter Other Asia, nes to export_csv/dataset_for_exporter_Other Asia, nes.csv
# Saved dataset for exporter Pakistan to export_csv/dataset_for_exporter_Pakistan.csv
# Saved dataset for exporter Panama to export_csv/dataset_for_exporter_Panama.csv
# Saved dataset for exporter Papua New Guinea to export_csv/dataset_for_exporter_Papua New Guinea.csv
# Saved dataset for exporter Peru to export_csv/dataset_for_exporter_Peru.csv
# Saved dataset for exporter Philippines to export_csv/dataset_for_exporter_Philippines.csv
# Saved dataset for exporter Poland to export_csv/dataset_for_exporter_Poland.csv
# Saved dataset for exporter Portugal to export_csv/dataset_for_exporter_Portugal.csv
# Saved dataset for exporter Rep. of Korea to export_csv/dataset_for_exporter_Rep. of Korea.csv
# Saved dataset for exporter Romania to export_csv/dataset_for_exporter_Romania.csv
# Saved dataset for exporter Russian Federation to export_csv/dataset_for_exporter_Russian Federation.csv
# Saved dataset for exporter Saudi Arabia to export_csv/dataset_for_exporter_Saudi Arabia.csv
# Saved dataset for exporter Serbia to export_csv/dataset_for_exporter_Serbia.csv
# Saved dataset for exporter Sierra Leone to export_csv/dataset_for_exporter_Sierra Leone.csv
# Saved dataset for exporter Singapore to export_csv/dataset_for_exporter_Singapore.csv
# Saved dataset for exporter Slovakia to export_csv/dataset_for_exporter_Slovakia.csv
# Saved dataset for exporter Slovenia to export_csv/dataset_for_exporter_Slovenia.csv
# Saved dataset for exporter South Africa to export_csv/dataset_for_exporter_South Africa.csv
# Saved dataset for exporter Spain to export_csv/dataset_for_exporter_Spain.csv
# Saved dataset for exporter Sri Lanka to export_csv/dataset_for_exporter_Sri Lanka.csv
# Saved dataset for exporter Suriname to export_csv/dataset_for_exporter_Suriname.csv
# Saved dataset for exporter Sweden to export_csv/dataset_for_exporter_Sweden.csv
# Saved dataset for exporter Switzerland to export_csv/dataset_for_exporter_Switzerland.csv
# Saved dataset for exporter Syria to export_csv/dataset_for_exporter_Syria.csv
# Saved dataset for exporter Tajikistan to export_csv/dataset_for_exporter_Tajikistan.csv
# Saved dataset for exporter Thailand to export_csv/dataset_for_exporter_Thailand.csv
# Saved dataset for exporter Tonga to export_csv/dataset_for_exporter_Tonga.csv
# Saved dataset for exporter Tunisia to export_csv/dataset_for_exporter_Tunisia.csv
# Saved dataset for exporter Turkmenistan to export_csv/dataset_for_exporter_Turkmenistan.csv
# Saved dataset for exporter Türkiye to export_csv/dataset_for_exporter_Türkiye.csv
# Saved dataset for exporter USA to export_csv/dataset_for_exporter_USA.csv
# Saved dataset for exporter Ukraine to export_csv/dataset_for_exporter_Ukraine.csv
# Saved dataset for exporter United Arab Emirates to export_csv/dataset_for_exporter_United Arab Emirates.csv
# Saved dataset for exporter United Kingdom to export_csv/dataset_for_exporter_United Kingdom.csv
# Saved dataset for exporter Uruguay to export_csv/dataset_for_exporter_Uruguay.csv
# Saved dataset for exporter Uzbekistan to export_csv/dataset_for_exporter_Uzbekistan.csv
# Saved dataset for exporter Venezuela to export_csv/dataset_for_exporter_Venezuela.csv
# Saved dataset for exporter Viet Nam to export_csv/dataset_for_exporter_Viet Nam.csv
# Saved dataset for exporter Yemen to export_csv/dataset_for_exporter_Yemen.csv
# Saved dataset for exporter Zambia to export_csv/dataset_for_exporter_Zambia.csv

# %%
# Out:
# {('Afghanistan', 'Germany'): 1.759, ('Afghanistan', 'Ireland'): 36.632, ('Afghanistan', 'United Kingdom'): 33.359, ('Afghanistan', 'USA'): 3.823, ('Albania', 'Switzerland'): 2.589, ('Algeria', 'Switzerland'): 14.555, ('Angola', 'USA'): 367.979, ('Argentina', 'France'): 3.313, ('Argentina', 'Hungary'): 0.192, ('Argentina', 'USA'): 159.839, ('Armenia', 'Switzerland'): 31.668, ('Armenia', 'United Kingdom'): 362.431, ('Australia', 'Finland'): 8.567, ('Australia', 'Germany'): 2.984, ('Australia', 'Ireland'): 11.188, ('Australia', 'Italy'): 6.303, ('Australia', 'Netherlands'): 1.391, ('Australia', 'New Zealand'): 22.597, ('Australia', 'Switzerland'): 1.732, ('Australia', 'United Kingdom'): 519.759, ('Australia', 'USA'): 46.462, ('Austria', 'Argentina'): 8.951, ('Austria', 'Australia'): 62.233, ('Austria', 'Belgium'): 2.92, ('Austria', 'Bulgaria'): 0.398, ('Austria', 'Canada'): 72.395, ('Austria', 'China'): 233.325, ('Austria', 'Croatia'): 1.885, ('Austria', 'Cyprus'): 1.237, ('Austria', 'Czechia'): 7.702, ('Austria', 'Denmark'): 1.531, ('Austria', 'Estonia'): 0.31, ('Austria', 'Finland'): 0.2, ('Austria', 'France'): 125.54, ('Austria', 'Germany'): 83.202, ('Austria', 'Greece'): 1.869, ('Austria', 'China, Hong Kong SAR'): 1143.926, ('Austria', 'Hungary'): 13.871, ('Austria', 'Ireland'): 4.08, ('Austria', 'Israel'): 56.432, ('Austria', 'Italy'): 36.132, ('Austria', 'Japan'): 254.361, ('Austria', 'Rep. of Korea'): 1.028, ('Austria', 'Lithuania'): 0.164, ('Austria', 'Luxembourg'): 0.269, ('Austria', 'Other Asia, nes'): 231.12, ('Austria', 'Netherlands'): 13.628, ('Austria', 'Norway'): 0.776, ('Austria', 'Poland'): 5.542, ('Austria', 'Portugal'): 3.874, ('Austria', 'Romania'): 2.847, ('Austria', 'Russian Federation'): 8.62, ('Austria', 'India'): 34.536, ('Austria', 'Slovakia'): 1.873, ('Austria', 'Slovenia'): 3.686, ('Austria', 'Spain'): 6.31, ('Austria', 'Sweden'): 0.805, ('Austria', 'Switzerland'): 444.043, ('Austria', 'Türkiye'): 4.16, ('Austria', 'United Kingdom'): 828.397, ('Austria', 'USA'): 1571.229, ('Azerbaijan', 'United Kingdom'): 24.165, ('Azerbaijan', 'USA'): 214.325, ('Bahrain', 'United Kingdom'): 3.817, ('Belgium', 'Australia'): 146.088, ('Belgium', 'Austria'): 3.159, ('Belgium', 'Canada'): 39.857, ('Belgium', 'Cayman Isds'): 1.895, ('Belgium', 'Chile'): 0.181, ('Belgium', 'China'): 1.363, ('Belgium', 'France'): 506.858, ('Belgium', 'Germany'): 129.552, ('Belgium', 'China, Hong Kong SAR'): 105.425, ('Belgium', 'Israel'): 48.595, ('Belgium', 'Italy'): 80.096, ('Belgium', 'Japan'): 49.251, ('Belgium', 'Rep. of Korea'): 11.427, ('Belgium', 'Luxembourg'): 0.16, ('Belgium', 'Mexico'): 2.582, ('Belgium', 'Other Asia, nes'): 3.218, ('Belgium', 'Netherlands'): 3.834, ('Belgium', 'New Zealand'): 1.264, ('Belgium', 'Norway'): 1.085, ('Belgium', 'Qatar'): 24.747, ('Belgium', 'Russian Federation'): 16.921, ('Belgium', 'India'): 26.326, ('Belgium', 'Singapore'): 9114.774, ('Belgium', 'Switzerland'): 259.432, ('Belgium', 'Thailand'): 1.369, ('Belgium', 'United Arab Emirates'): 0.65, ('Belgium', 'Türkiye'): 6.965, ('Belgium', 'United Kingdom'): 2275.506, ('Belgium', 'USA'): 7288.249, ('Bolivia (Plurinational State of)', 'Germany'): 3.637, ('Bolivia (Plurinational State of)', 'USA'): 22.701, ('Brazil', 'Australia'): 12.121, ('Brazil', 'Canada'): 4.719, ('Brazil', 'France'): 878.372, ('Brazil', 'China, Hong Kong SAR'): 0.006, ('Brazil', 'Malta'): 0.055, ('Brazil', 'Norway'): 1.348, ('Brazil', 'Panama'): 0.043, ('Brazil', 'Singapore'): 0.058, ('Brazil', 'Switzerland'): 0.856, ('Brazil', 'United Kingdom'): 3.985, ('Brazil', 'USA'): 13.641, ('Bulgaria', 'Netherlands'): 0.225, ('Bulgaria', 'USA'): 26.423, ('Cambodia', 'Canada'): 4.473, ('Cambodia', 'USA'): 51.343, ('Cameroon', 'USA'): 494.682, ('Canada', 'Austria'): 6.531, ('Canada', 'Belgium'): 1.673, ('Canada', 'China'): 22.358, ('Canada', 'Czechia'): 0.637, ('Canada', 'Denmark'): 0.187, ('Canada', 'France'): 7.324, ('Canada', 'Germany'): 0.769, ('Canada', 'China, Hong Kong SAR'): 21.513, ('C ...

# %%
# Initialize a dictionary to store edges with weights
edges = defaultdict(float)

# Iterate through the datasets_by_exporter dictionary
for exporter, df in datasets_by_exporter.items():
    # Iterate through each row in the DataFrame
    for idx, row in df.iterrows():
        # Extract importer (j), exporter (i), and transaction value (v)
        exporter = idx[1]  # 'i' level from MultiIndex
        importer = idx[2]  # 'j' level from MultiIndex
        value = idx[4]   # 'v' column value

        # Add the value to the corresponding (importer, exporter) edge
        edges[(exporter, importer)] += value

# Convert defaultdict back to a normal dictionary (optional)
edges = dict(edges)

print(edges)
# Out:
# {('Afghanistan', 'Germany'): 1.759, ('Afghanistan', 'Ireland'): 36.632, ('Afghanistan', 'United Kingdom'): 33.359, ('Afghanistan', 'USA'): 3.823, ('Albania', 'Switzerland'): 2.589, ('Algeria', 'Switzerland'): 14.555, ('Angola', 'USA'): 367.979, ('Argentina', 'France'): 3.313, ('Argentina', 'Hungary'): 0.192, ('Argentina', 'USA'): 159.839, ('Armenia', 'Switzerland'): 31.668, ('Armenia', 'United Kingdom'): 362.431, ('Australia', 'Finland'): 8.567, ('Australia', 'Germany'): 2.984, ('Australia', 'Ireland'): 11.188, ('Australia', 'Italy'): 6.303, ('Australia', 'Netherlands'): 1.391, ('Australia', 'New Zealand'): 22.597, ('Australia', 'Switzerland'): 1.732, ('Australia', 'United Kingdom'): 519.759, ('Australia', 'USA'): 46.462, ('Austria', 'Argentina'): 8.951, ('Austria', 'Australia'): 62.233, ('Austria', 'Belgium'): 2.92, ('Austria', 'Bulgaria'): 0.398, ('Austria', 'Canada'): 72.395, ('Austria', 'China'): 233.325, ('Austria', 'Croatia'): 1.885, ('Austria', 'Cyprus'): 1.237, ('Austria', 'Czechia'): 7.702, ('Austria', 'Denmark'): 1.531, ('Austria', 'Estonia'): 0.31, ('Austria', 'Finland'): 0.2, ('Austria', 'France'): 125.54, ('Austria', 'Germany'): 83.202, ('Austria', 'Greece'): 1.869, ('Austria', 'China, Hong Kong SAR'): 1143.926, ('Austria', 'Hungary'): 13.871, ('Austria', 'Ireland'): 4.08, ('Austria', 'Israel'): 56.432, ('Austria', 'Italy'): 36.132, ('Austria', 'Japan'): 254.361, ('Austria', 'Rep. of Korea'): 1.028, ('Austria', 'Lithuania'): 0.164, ('Austria', 'Luxembourg'): 0.269, ('Austria', 'Other Asia, nes'): 231.12, ('Austria', 'Netherlands'): 13.628, ('Austria', 'Norway'): 0.776, ('Austria', 'Poland'): 5.542, ('Austria', 'Portugal'): 3.874, ('Austria', 'Romania'): 2.847, ('Austria', 'Russian Federation'): 8.62, ('Austria', 'India'): 34.536, ('Austria', 'Slovakia'): 1.873, ('Austria', 'Slovenia'): 3.686, ('Austria', 'Spain'): 6.31, ('Austria', 'Sweden'): 0.805, ('Austria', 'Switzerland'): 444.043, ('Austria', 'Türkiye'): 4.16, ('Austria', 'United Kingdom'): 828.397, ('Austria', 'USA'): 1571.229, ('Azerbaijan', 'United Kingdom'): 24.165, ('Azerbaijan', 'USA'): 214.325, ('Bahrain', 'United Kingdom'): 3.817, ('Belgium', 'Australia'): 146.088, ('Belgium', 'Austria'): 3.159, ('Belgium', 'Canada'): 39.857, ('Belgium', 'Cayman Isds'): 1.895, ('Belgium', 'Chile'): 0.181, ('Belgium', 'China'): 1.363, ('Belgium', 'France'): 506.858, ('Belgium', 'Germany'): 129.552, ('Belgium', 'China, Hong Kong SAR'): 105.425, ('Belgium', 'Israel'): 48.595, ('Belgium', 'Italy'): 80.096, ('Belgium', 'Japan'): 49.251, ('Belgium', 'Rep. of Korea'): 11.427, ('Belgium', 'Luxembourg'): 0.16, ('Belgium', 'Mexico'): 2.582, ('Belgium', 'Other Asia, nes'): 3.218, ('Belgium', 'Netherlands'): 3.834, ('Belgium', 'New Zealand'): 1.264, ('Belgium', 'Norway'): 1.085, ('Belgium', 'Qatar'): 24.747, ('Belgium', 'Russian Federation'): 16.921, ('Belgium', 'India'): 26.326, ('Belgium', 'Singapore'): 9114.774, ('Belgium', 'Switzerland'): 259.432, ('Belgium', 'Thailand'): 1.369, ('Belgium', 'United Arab Emirates'): 0.65, ('Belgium', 'Türkiye'): 6.965, ('Belgium', 'United Kingdom'): 2275.506, ('Belgium', 'USA'): 7288.249, ('Bolivia (Plurinational State of)', 'Germany'): 3.637, ('Bolivia (Plurinational State of)', 'USA'): 22.701, ('Brazil', 'Australia'): 12.121, ('Brazil', 'Canada'): 4.719, ('Brazil', 'France'): 878.372, ('Brazil', 'China, Hong Kong SAR'): 0.006, ('Brazil', 'Malta'): 0.055, ('Brazil', 'Norway'): 1.348, ('Brazil', 'Panama'): 0.043, ('Brazil', 'Singapore'): 0.058, ('Brazil', 'Switzerland'): 0.856, ('Brazil', 'United Kingdom'): 3.985, ('Brazil', 'USA'): 13.641, ('Bulgaria', 'Netherlands'): 0.225, ('Bulgaria', 'USA'): 26.423, ('Cambodia', 'Canada'): 4.473, ('Cambodia', 'USA'): 51.343, ('Cameroon', 'USA'): 494.682, ('Canada', 'Austria'): 6.531, ('Canada', 'Belgium'): 1.673, ('Canada', 'China'): 22.358, ('Canada', 'Czechia'): 0.637, ('Canada', 'Denmark'): 0.187, ('Canada', 'France'): 7.324, ('Canada', 'Germany'): 0.769, ('Canada', 'China, Hong Kong SAR'): 21.513, ('C ...

# %%
edges.keys()
# Out:
# dict_keys([('Afghanistan', 'Germany'), ('Afghanistan', 'Ireland'), ('Afghanistan', 'United Kingdom'), ('Afghanistan', 'USA'), ('Albania', 'Switzerland'), ('Algeria', 'Switzerland'), ('Angola', 'USA'), ('Argentina', 'France'), ('Argentina', 'Hungary'), ('Argentina', 'USA'), ('Armenia', 'Switzerland'), ('Armenia', 'United Kingdom'), ('Australia', 'Finland'), ('Australia', 'Germany'), ('Australia', 'Ireland'), ('Australia', 'Italy'), ('Australia', 'Netherlands'), ('Australia', 'New Zealand'), ('Australia', 'Switzerland'), ('Australia', 'United Kingdom'), ('Australia', 'USA'), ('Austria', 'Argentina'), ('Austria', 'Australia'), ('Austria', 'Belgium'), ('Austria', 'Bulgaria'), ('Austria', 'Canada'), ('Austria', 'China'), ('Austria', 'Croatia'), ('Austria', 'Cyprus'), ('Austria', 'Czechia'), ('Austria', 'Denmark'), ('Austria', 'Estonia'), ('Austria', 'Finland'), ('Austria', 'France'), ('Austria', 'Germany'), ('Austria', 'Greece'), ('Austria', 'China, Hong Kong SAR'), ('Austria', 'Hungary'), ('Austria', 'Ireland'), ('Austria', 'Israel'), ('Austria', 'Italy'), ('Austria', 'Japan'), ('Austria', 'Rep. of Korea'), ('Austria', 'Lithuania'), ('Austria', 'Luxembourg'), ('Austria', 'Other Asia, nes'), ('Austria', 'Netherlands'), ('Austria', 'Norway'), ('Austria', 'Poland'), ('Austria', 'Portugal'), ('Austria', 'Romania'), ('Austria', 'Russian Federation'), ('Austria', 'India'), ('Austria', 'Slovakia'), ('Austria', 'Slovenia'), ('Austria', 'Spain'), ('Austria', 'Sweden'), ('Austria', 'Switzerland'), ('Austria', 'Türkiye'), ('Austria', 'United Kingdom'), ('Austria', 'USA'), ('Azerbaijan', 'United Kingdom'), ('Azerbaijan', 'USA'), ('Bahrain', 'United Kingdom'), ('Belgium', 'Australia'), ('Belgium', 'Austria'), ('Belgium', 'Canada'), ('Belgium', 'Cayman Isds'), ('Belgium', 'Chile'), ('Belgium', 'China'), ('Belgium', 'France'), ('Belgium', 'Germany'), ('Belgium', 'China, Hong Kong SAR'), ('Belgium', 'Israel'), ('Belgium', 'Italy'), ('Belgium', 'Japan'), ('Belgium', 'Rep. of Korea'), ('Belgium', 'Luxembourg'), ('Belgium', 'Mexico'), ('Belgium', 'Other Asia, nes'), ('Belgium', 'Netherlands'), ('Belgium', 'New Zealand'), ('Belgium', 'Norway'), ('Belgium', 'Qatar'), ('Belgium', 'Russian Federation'), ('Belgium', 'India'), ('Belgium', 'Singapore'), ('Belgium', 'Switzerland'), ('Belgium', 'Thailand'), ('Belgium', 'United Arab Emirates'), ('Belgium', 'Türkiye'), ('Belgium', 'United Kingdom'), ('Belgium', 'USA'), ('Bolivia (Plurinational State of)', 'Germany'), ('Bolivia (Plurinational State of)', 'USA'), ('Brazil', 'Australia'), ('Brazil', 'Canada'), ('Brazil', 'France'), ('Brazil', 'China, Hong Kong SAR'), ('Brazil', 'Malta'), ('Brazil', 'Norway'), ('Brazil', 'Panama'), ('Brazil', 'Singapore'), ('Brazil', 'Switzerland'), ('Brazil', 'United Kingdom'), ('Brazil', 'USA'), ('Bulgaria', 'Netherlands'), ('Bulgaria', 'USA'), ('Cambodia', 'Canada'), ('Cambodia', 'USA'), ('Cameroon', 'USA'), ('Canada', 'Austria'), ('Canada', 'Belgium'), ('Canada', 'China'), ('Canada', 'Czechia'), ('Canada', 'Denmark'), ('Canada', 'France'), ('Canada', 'Germany'), ('Canada', 'China, Hong Kong SAR'), ('Canada', 'Ireland'), ('Canada', 'Italy'), ('Canada', 'Japan'), ('Canada', 'Netherlands'), ('Canada', 'Spain'), ('Canada', 'Sweden'), ('Canada', 'Switzerland'), ('Canada', 'United Kingdom'), ('Canada', 'USA'), ('Chile', 'Australia'), ('Chile', 'France'), ('Chile', 'USA'), ('China', 'Australia'), ('China', 'Austria'), ('China', 'Cambodia'), ('China', 'Canada'), ('China', 'Chile'), ('China', 'Czechia'), ('China', 'Finland'), ('China', 'France'), ('China', 'Germany'), ('China', 'China, Hong Kong SAR'), ('China', 'Ireland'), ('China', 'Italy'), ('China', 'Japan'), ('China', 'Rep. of Korea'), ('China', 'Lebanon'), ('China', 'Lithuania'), ('China', 'China, Macao SAR'), ('China', 'Malaysia'), ('China', 'Other Asia, nes'), ('China', 'Netherlands'), ('China', 'New Zealand'), ('China', 'Norway'), ('China', 'Pakistan'), ('China', 'Portugal'), ('China', 'Singapore'), ('China', 'Slovakia'), ('Ch ...

# %%
exporter_list = set()
importer_list = set()
for key, value in edges.items():
    first_entry = key[0]  # Access the first element of the tuple
    second_entry = key[1]
    exporter_list.add(first_entry)
    importer_list.add(second_entry)

print(len(importer_list))
print(len(exporter_list))
# Out:
# 95
# 110

# %% [markdown]
# ### Directed Graph G
# To use with the class weightedDiGraph

# %%
# Path to the folder containing the CSV files for each exporter
path_to_csvs = "export_csv/*.csv"  # Adjust this path as needed

# Initialize a directed graph
G = nx.DiGraph()

# Load each CSV file and create edges for the directed graph
for file in glob.glob(path_to_csvs):
    # Read the CSV file
    df = pd.read_csv(file, index_col=[0, 1, 2])  # Assuming Multi-Index (t, i, j)
    
    # Ensure 'q' is numeric and coerce errors to NaN
    df['v'] = pd.to_numeric(df['v'], errors='coerce')

    # Iterate over each row and add edges to the graph
    for (t, exporter, importer), group in df.groupby(level=[0, 1, 2]):
        total_quantity = group['v'].sum(skipna=True)  # Sum quantities for the current exporter-importer pair
        if pd.notna(total_quantity):  # Ensure total_quantity is not NaN
            G.add_edge(exporter, importer, weight=total_quantity)

# Optional: You can visualize or analyze the graph now
print("Nodes in the graph:", G.number_of_nodes())
print("Edges in the graph:", G.number_of_edges())

# Optional: To save the graph to a file (e.g., GML format)
#nx.write_gml(G, "export_import_graph.gml")

# %% [markdown]
# ### Bipartite Graph B
# For use with class weightedBipartiteGraph

# %%
# Create an empty directed graph
B = nx.DiGraph()

# Distinguish exporters and importers by prefixing node names
for (importer, exporter), weight in edges.items():
    exporter_node = f"e_{exporter}"  # Prefix exporter nodes
    importer_node = f"i_{importer}"  # Prefix importer nodes
    
    # Add the edge with the weight
    B.add_edge(exporter_node, importer_node, weight=weight)


def graph_info(G):
    info = (
        f"Graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.\n"
        f"Is directed: {G.is_directed()}\n"
        f"Average degree: {sum(dict(G.degree()).values()) / G.number_of_nodes():.2f}"
    )
    return info

print(graph_info(B))
print()
print(nx.is_bipartite(B))
# Out:
# Graph with 205 nodes and 952 edges.
# Is directed: True
# Average degree: 9.29
#
# True

# %%
# Draw the graph (this may not work well for very large graphs)
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(B)  # positions for all nodes
nx.draw_networkx_nodes(B, pos, node_size=700)
nx.draw_networkx_edges(B, pos, arrowstyle='-|>', arrowsize=20)
nx.draw_networkx_labels(B, pos, font_size=10)
edge_labels = nx.get_edge_attributes(B, 'weight')
nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

plt.title("Imports/Exports Directed Graph")
plt.show()

# %%
class weightedDiGraph:
    '''
    Class gathering several functions for working with our standard directed, weighted bigraph. 
    Does not work with bipartite networks.
    
    
    Functions:
        _counting_degree_diGraph = 
        _cumulative_degree_plot = 
        _closeness_centrality = 
        _average_neighbor_degree = 
        _betweenness_centrality = 
        _clustering_coefficient = 
        _maximum_shortest_path = 
    '''
    
    
    
    def __init__(self, graph = None):
        self._graph = graph

    def _counting_degrees_diGraph(self):
        '''
        A function that counts the total number of in and out degrees for each key value. Returns two lists of tuples.

            Input:
        graph = Your nx.diGraph

            Output:
        out_degree_list = A list of tuples, with the first value corresponding to the degree and the second value to nodes with
        said degree in the network. e.g (0, 25) -> 25 nodes have an outdegree 0
        in_degree_list = Same as above.
        '''
        out_degree = list(self._graph.out_degree)
        out_degree.sort()
        in_degree = list(self._graph.in_degree)
        in_degree.sort()


        out_degree_totals = []
        out_degree_counts = {}
        out_degree_list = []
        for i in out_degree:
            out_degree_totals.append(i[1])
        for i in out_degree_totals:
            out_degree_counts[i] = out_degree_totals.count(i)
        for key in out_degree_counts:
            out_degree_list.append((key, out_degree_counts[key]))


        # ADDED CODE TO ADD 0 FREQUENCY COUNTS, UP TO HIGHEST VALUE
        out_degree_list.sort()

        min_out_degree = out_degree_list[0][0]  # Get the minimum degree value
        max_out_degree = out_degree_list[-1][0]  # Get the maximum degree value

        # Loop over the range from min to max, adding missing values with count 0
        for degree in range(min_out_degree, max_out_degree + 1):
            if degree not in out_degree_counts:
                out_degree_list.append((degree, 0))



        in_degree_totals = []
        in_degree_counts = {}
        in_degree_list = []
        for i in in_degree:
            in_degree_totals.append(i[1])
        for i in in_degree_totals:
            in_degree_counts[i] = in_degree_totals.count(i)
        for key in in_degree_counts:
            in_degree_list.append((key, in_degree_counts[key]))



        # ADDED CODE TO ADD 0 FREQUENCY COUNTS, UP TO HIGHEST VALUE
        out_degree_list.sort()

        min_in_degree = in_degree_list[0][0]  # Get the minimum degree value
        max_in_degree = in_degree_list[-1][0]  # Get the maximum degree value

        # Loop over the range from min to max, adding missing values with count 0
        for degree in range(min_in_degree, max_in_degree + 1):
            if degree not in in_degree_counts:
                in_degree_list.append((degree, 0))


        out_degree_list.sort()
        in_degree_list.sort()

        return out_degree_list, in_degree_list


    def _cumulative_degree_plot(self):
        '''
        To be expanded - A simple plot function for creating a cumulative degree plot

            Input:
        A degree list of tuples, as created by counting_degree_diGraph()

            Output:
        A plt.plot created from the two values in the tuples.
        '''
        out_degree_list, in_degree_list = self._counting_degrees_diGraph()
        
        out_degree_index_list = []
        out_degree_value_list = []
        out_degree_cumul_list = []

        for i in out_degree_list:
            out_degree_index_list.append(i[0])
            out_degree_value_list.append(i[1])

        for i in range(len(out_degree_index_list)):
            out_degree_cumul_list.append(np.sum(out_degree_value_list[i:]))
            
            
            
            
        in_degree_index_list = []
        in_degree_value_list = []
        in_degree_cumul_list = []

        for i in in_degree_list:
            in_degree_index_list.append(i[0])
            in_degree_value_list.append(i[1])

        for i in range(len(in_degree_index_list)):
            in_degree_cumul_list.append(np.sum(in_degree_value_list[i:]))


        #list1 = []
        #list2 = []

        #for i in range(len(degree_list)):
        #    list1.append(degree_list[i][0])
        #    list2.append(degree_list[i][1])

        
        # Create plots
        fig, ax = plt.subplots()
        out_plot, = ax.plot(out_degree_index_list, out_degree_cumul_list, label="Out-Degree", color="blue")
        in_plot, = ax.plot(in_degree_index_list, in_degree_cumul_list, label="In-Degree", color="orange")

        ax.set_xscale("log")
        ax.set_yscale("log")
        ax.set_xlabel("Degree")
        ax.set_ylabel("Cumulative Count")
        ax.set_title("Cumulative degree plot")
        ax.legend()

        return out_plot, in_plot
    

    def _closeness_centrality(self):
        '''
        Small function for finding the node centrality of our network. Returns a sorted list of tuples and the highest value node.

        Input:
            graph = A networkx graph

        Output:
            node_centrality_tuples = A sorted list of tuples for each of the nodes, with their degree centrality.
            maxtup = A tuple for the highest value node.
        '''
        node_centrality = nx.degree_centrality(self._graph)
        node_centrality_tuples = sorted(node_centrality.items())
        maxtup = (0,0)


        for i in node_centrality_tuples:
            if i[1] > maxtup[1]:
                maxtup = i

        return node_centrality_tuples, maxtup

    def _average_neighbor_degree(self):
        '''
        Small function for finding the average degree of the neighbors to each node in the graph. Good for finding hubs.

        Input:
            graph = A networkx graph

        Output:
            avg_neighbor_degree_tuples = A sorted list of tuples for each of the nodes, with their average neighbor degree.
            maxdic = A dictionary of the highest value nodes.

            OPTIONAL maxtup = A tuple for the highest value node.
        '''

        average_neighbor_degree_dict = nx.average_neighbor_degree(self._graph)

        avg_neighbor_degree_tuples = sorted(average_neighbor_degree_dict.items())
        maxtup = (0,0)
        maxdic = {}

        for i in avg_neighbor_degree_tuples:
            if i[1] > maxtup[1]:
                maxtup = i

        for i in avg_neighbor_degree_tuples:
            if i[1] == maxtup[1]:
                maxdic[i[0]] = i[1]

        return avg_neighbor_degree_tuples, maxdic #, maxtup

    def _betweenness_centrality(self):
        '''
        Small function for finding the betweenness centrality - 
        Betweenness centrality is a measure used in network analysis to quantify the importance of a node within a graph 
        based on the number of shortest paths that pass through it. 
        It reflects how much a node acts as a bridge or mediator in the network.

        Input:
            graph = A networkx graph

        Output:
            betw_cen_tuples = A sorted list of tuples for each of the nodes, with their betweenness centrality.
            maxtup = A tuple for the highest value node.

        '''

        betw_cen = nx.betweenness_centrality(self._graph)

        betw_cen_tuples = sorted(betw_cen.items())
        maxtup = (0,0)

        for i in betw_cen_tuples:
            if i[1] > maxtup[1]:
                maxtup = i

        return betw_cen_tuples, maxtup


    def _clustering_coefficient(self):
        '''
        Small function for finding the clustering coefficient

        Input:
            graph = A networkx graph

        Output:
            clust_co_tuples = A sorted list of tuples for each of the nodes, with their clustering coefficient
            maxdic = A dictionary for the highest value nodes

            OPTIONAL maxtup = A tuple for the maximum value. Logically not sound, as many nodes will share clustering coefficients.
        '''

        clust_co = nx.clustering(self._graph)

        clust_co_tuples = sorted(clust_co.items())

        maxtup = (0,0)
        maxdic = {}

        for i in clust_co_tuples:
            if i[1] > maxtup[1]:
                maxtup = i

        for i in clust_co_tuples:
            if i[1] == maxtup[1]:
                maxdic[i[0]] = i[1]

        return clust_co_tuples, maxdic #, maxtup

    def _maximum_shortest_path(self):
        '''
        As we have a weakly connected graph, we can not directly find the diameter of our graph.
        Instead we must find the longest path within any two connected nodes in the network.

        Input:
            graph = A networkx graph

        Output:
            diameter = An integer that shows the longest path between two connected nodes.

        '''
        diameter = max([max(j.values()) for (i,j) in nx.shortest_path_length(self._graph)]) # maximum distance of a list containing the shortest paths between any two nodes in the graph (computed with Dijkstra's algorithm)

        # If you want to understand how the code works/runs, use the following:
        #for (i, j) in nx.shortest_path_length(graph):
        #    print(f'this is i: {i}')
        #    print(f'this is j: {j.values()}')

        # TO BE ADDED
        # Save the i-country to understand which nodes have the longest path.

        return diameter
    
    def summary(self):
        # Node degree centrality
        node_centrality_tuple_list, max_node_centrality = self._closeness_centrality()
        avg_neighbor_deg_tuple, max_avg_neighbor_deg = self._average_neighbor_degree()
        between_centr_tuple, max_between_centr = self._betweenness_centrality()
        clust_coe_tup, maxdic_clust = self._clustering_coefficient()
        longest_path = self._maximum_shortest_path()

        print(f'Our maximum node centrality is: {max_node_centrality}')
        print()
        print(f'Our maximum average neighbor degree nodes are: {list(max_avg_neighbor_deg.keys())} and they have value {list(max_avg_neighbor_deg.values())[0]}')
        print()
        print(f'Our maximum betweenness centrality node is: {max_between_centr}')
        print()
        print(f'Our maximum clustering coefficient nodes are: {list(maxdic_clust.keys())} and they have value {list(maxdic_clust.values())[0]}')
        print()
        print(f'Our longest path in the network is: {longest_path}')
    
    
    # def _graph_transitivity(self):
    # nx.transitivity(self._graph)

# %%
# Calling our class and all functions:
G_graph_test = weightedDiGraph(B)

G_graph_test._cumulative_degree_plot()
# Out:
# (<matplotlib.lines.Line2D at 0x2653c0e7510>,
#  <matplotlib.lines.Line2D at 0x26567c0f9d0>)

# %%
B.nodes()
# Out:
# NodeView(('e_Germany', 'i_Afghanistan', 'e_Ireland', 'e_United Kingdom', 'e_USA', 'e_Switzerland', 'i_Albania', 'i_Algeria', 'i_Angola', 'e_France', 'i_Argentina', 'e_Hungary', 'i_Armenia', 'e_Finland', 'i_Australia', 'e_Italy', 'e_Netherlands', 'e_New Zealand', 'e_Argentina', 'i_Austria', 'e_Australia', 'e_Belgium', 'e_Bulgaria', 'e_Canada', 'e_China', 'e_Croatia', 'e_Cyprus', 'e_Czechia', 'e_Denmark', 'e_Estonia', 'e_Greece', 'e_China, Hong Kong SAR', 'e_Israel', 'e_Japan', 'e_Rep. of Korea', 'e_Lithuania', 'e_Luxembourg', 'e_Other Asia, nes', 'e_Norway', 'e_Poland', 'e_Portugal', 'e_Romania', 'e_Russian Federation', 'e_India', 'e_Slovakia', 'e_Slovenia', 'e_Spain', 'e_Sweden', 'e_Türkiye', 'i_Azerbaijan', 'i_Bahrain', 'i_Belgium', 'e_Austria', 'e_Cayman Isds', 'e_Chile', 'e_Mexico', 'e_Qatar', 'e_Singapore', 'e_Thailand', 'e_United Arab Emirates', 'i_Bolivia (Plurinational State of)', 'i_Brazil', 'e_Malta', 'e_Panama', 'i_Bulgaria', 'i_Cambodia', 'i_Cameroon', 'i_Canada', 'i_Chile', 'i_China', 'e_Cambodia', 'e_Lebanon', 'e_China, Macao SAR', 'e_Malaysia', 'e_Pakistan', 'e_South Africa', 'i_China, Hong Kong SAR', 'i_Colombia', 'i_Costa Rica', 'i_Croatia', 'i_Cyprus', 'i_Czechia', 'i_Dem. Rep. of the Congo', 'i_Denmark', 'i_Dominican Rep.', 'i_Egypt', 'i_Estonia', 'i_Ethiopia', 'i_Finland', 'e_Andorra', 'i_France', 'e_Brazil', 'e_Guatemala', 'e_Indonesia', 'e_Kuwait', 'e_Morocco', 'e_Oman', 'e_Saudi Arabia', 'e_Viet Nam', 'i_French Polynesia', 'i_Georgia', 'i_Germany', 'e_Georgia', 'e_Ukraine', 'i_Greece', 'i_Guatemala', 'i_Hungary', 'i_India', 'i_Indonesia', 'i_Iran', 'i_Iraq', 'i_Ireland', 'i_Israel', 'i_Italy', 'i_Jamaica', 'i_Japan', 'i_Jordan', 'i_Kenya', "i_Lao People's Dem. Rep.", 'i_Latvia', 'i_Lebanon', 'i_Libya', 'i_Lithuania', 'i_Luxembourg', 'i_Madagascar', 'i_Mali', 'i_Malta', 'i_Mexico', 'i_Morocco', 'i_Myanmar', 'i_Namibia', 'i_Nepal', 'i_Netherlands', 'i_New Zealand', 'i_Niger', 'i_Nigeria', 'i_Norway', 'i_Oman', 'i_Other Asia, nes', 'i_Pakistan', 'i_Panama', 'i_Papua New Guinea', 'i_Peru', 'i_Philippines', 'i_Poland', 'i_Portugal', 'e_Iceland', 'i_Rep. of Korea', 'i_Romania', 'i_Russian Federation', 'i_Saudi Arabia', 'i_Serbia', 'i_Sierra Leone', 'i_Singapore', 'i_Slovakia', 'i_Slovenia', 'i_South Africa', 'e_Namibia', 'i_Spain', 'e_Costa Rica', 'e_Iraq', 'i_Sri Lanka', 'i_Suriname', 'i_Sweden', 'i_Switzerland', 'e_Br. Virgin Isds', 'e_Latvia', 'i_Syria', 'i_Tajikistan', 'i_Thailand', 'i_Tonga', 'i_Tunisia', 'i_Turkmenistan', 'i_Türkiye', 'i_USA', 'e_Armenia', 'e_Bermuda', 'e_Dominican Rep.', 'e_Maldives', 'e_Nepal', 'e_Aruba', 'e_Nigeria', 'e_Peru', 'e_Serbia', 'e_Uzbekistan', 'i_Ukraine', 'i_United Arab Emirates', 'e_Albania', 'i_United Kingdom', 'e_Azerbaijan', 'e_Bahrain', 'e_Myanmar', 'e_Gibraltar', 'e_Jordan', 'e_Mongolia', 'e_Nicaragua', 'e_Palau', 'e_Uganda', 'e_Yemen', 'i_Uruguay', 'i_Uzbekistan', 'i_Venezuela', 'i_Viet Nam', 'i_Yemen', 'i_Zambia'))

# %%
bpt.sets(B)[0]
# Out:
# {'e_Albania',
#  'e_Andorra',
#  'e_Argentina',
#  'e_Armenia',
#  'e_Aruba',
#  'e_Australia',
#  'e_Austria',
#  'e_Azerbaijan',
#  'e_Bahrain',
#  'e_Belgium',
#  'e_Bermuda',
#  'e_Br. Virgin Isds',
#  'e_Brazil',
#  'e_Bulgaria',
#  'e_Cambodia',
#  'e_Canada',
#  'e_Cayman Isds',
#  'e_Chile',
#  'e_China',
#  'e_China, Hong Kong SAR',
#  'e_China, Macao SAR',
#  'e_Costa Rica',
#  'e_Croatia',
#  'e_Cyprus',
#  'e_Czechia',
#  'e_Denmark',
#  'e_Dominican Rep.',
#  'e_Estonia',
#  'e_Finland',
#  'e_France',
#  'e_Georgia',
#  'e_Germany',
#  'e_Gibraltar',
#  'e_Greece',
#  'e_Guatemala',
#  'e_Hungary',
#  'e_Iceland',
#  'e_India',
#  'e_Indonesia',
#  'e_Iraq',
#  'e_Ireland',
#  'e_Israel',
#  'e_Italy',
#  'e_Japan',
#  'e_Jordan',
#  'e_Kuwait',
#  'e_Latvia',
#  'e_Lebanon',
#  'e_Lithuania',
#  'e_Luxembourg',
#  'e_Malaysia',
#  'e_Maldives',
#  'e_Malta',
#  'e_Mexico',
#  'e_Mongolia',
#  'e_Morocco',
#  'e_Myanmar',
#  'e_Namibia',
#  'e_Nepal',
#  'e_Netherlands',
#  'e_New Zealand',
#  'e_Nicaragua',
#  'e_Nigeria',
#  'e_Norway',
#  'e_Oman',
#  'e_Other Asia, nes',
#  'e_Pakistan',
#  'e_Palau',
#  'e_Panama',
#  'e_Peru',
#  'e_Poland',
#  'e_Portugal',
#  'e_Qatar',
#  'e_Rep. of Korea',
#  'e_Romania',
#  'e_Russian Federation',
#  'e_Saudi Arabia',
#  'e_Serbia',
#  'e_Singapore',
#  'e_Slovakia',
#  'e_Slovenia',
#  'e_South Africa',
#  'e_Spain',
#  'e_Sweden',
#  'e_Switzerland',
#  'e_Thailand',
#  'e_Türkiye',
#  'e_USA',
#  'e_Uganda',
#  'e_Ukraine',
#  'e_United Arab Emirates',
#  'e_United Kingdom',
#  'e_Uzbekistan',
#  'e_Viet Nam',
#  'e_Yemen'}

# %%
bipartite_degrees_exporters = list(bpt.degrees(B, bpt.sets(B)[1]))

# %%
bipartite_degrees_exporters[0]
# Out:
# DiDegreeView({'e_Oman': 3, 'e_Poland': 8, 'e_Other Asia, nes': 12, 'e_United Arab Emirates': 21, 'e_Br. Virgin Isds': 1, 'e_Hungary': 9, 'e_Uganda': 1, 'e_Ireland': 21, 'e_Ukraine': 2, 'e_Australia': 31, 'e_Namibia': 3, 'e_Lebanon': 4, 'e_Bulgaria': 8, 'e_Portugal': 10, 'e_Iraq': 1, 'e_Albania': 1, 'e_Palau': 1, 'e_Türkiye': 10, 'e_Denmark': 13, 'e_Serbia': 2, 'e_Japan': 20, 'e_Malta': 7, 'e_Armenia': 1, 'e_Canada': 35, 'e_Nigeria': 1, 'e_Russian Federation': 7, 'e_Nepal': 1, 'e_Panama': 3, 'e_Cambodia': 1, 'e_Israel': 16, 'e_Cyprus': 9, 'e_Mexico': 6, 'e_Myanmar': 1, 'e_South Africa': 6, 'e_Belgium': 19, 'e_Yemen': 1, 'e_Czechia': 13, 'e_Brazil': 3, 'e_Norway': 19, 'e_Jordan': 1, 'e_Rep. of Korea': 17, 'e_Gibraltar': 1, 'e_India': 9, 'e_Nicaragua': 1, 'e_Iceland': 2, 'e_Bahrain': 1, 'e_Thailand': 5, 'e_Germany': 37, 'e_Peru': 1, 'e_Argentina': 2, 'e_Latvia': 2, 'e_Uzbekistan': 2, 'e_Netherlands': 36, 'e_Georgia': 2, 'e_Dominican Rep.': 1, 'e_Malaysia': 10, 'e_New Zealand': 10, 'e_Qatar': 5, 'e_Sweden': 14, 'e_Greece': 8, 'e_France': 33, 'e_Cayman Isds': 3, 'e_Viet Nam': 5, 'e_Mongolia': 1, 'e_Morocco': 3, 'e_Kuwait': 7, 'e_Luxembourg': 10, 'e_Slovakia': 11, 'e_Guatemala': 2, 'e_United Kingdom': 63, 'e_Estonia': 5, 'e_Singapore': 17, 'e_Indonesia': 4, 'e_China, Hong Kong SAR': 22, 'e_Pakistan': 1, 'e_Azerbaijan': 1, 'e_Slovenia': 6, 'e_China': 21, 'e_Saudi Arabia': 4, 'e_Finland': 10, 'e_Costa Rica': 1, 'e_Romania': 6, 'e_Aruba': 1, 'e_Spain': 18, 'e_Switzerland': 45, 'e_Croatia': 6, 'e_Andorra': 1, 'e_China, Macao SAR': 8, 'e_Italy': 19, 'e_USA': 81, 'e_Lithuania': 9, 'e_Chile': 7, 'e_Austria': 20, 'e_Bermuda': 2, 'e_Maldives': 1})

# %%
bipartite_exporters = bpt.sets(B)[0]
bipartite_importers = bpt.sets(B)[1]

# %%
bpt.closeness_centrality(B, bpt.sets(B)[1])
# Out:
# {'i_Luxembourg': 0.0,
#  'i_Lebanon': 0.0,
#  'i_Philippines': 0.0,
#  'i_Uruguay': 0.0,
#  'i_Germany': 0.0,
#  'i_Angola': 0.0,
#  'i_Kenya': 0.0,
#  'i_Jamaica': 0.0,
#  'i_Papua New Guinea': 0.0,
#  'i_Madagascar': 0.0,
#  'i_Brazil': 0.0,
#  'i_Venezuela': 0.0,
#  'i_Algeria': 0.0,
#  'i_Suriname': 0.0,
#  'i_Syria': 0.0,
#  'i_Sri Lanka': 0.0,
#  'i_India': 0.0,
#  'i_Ukraine': 0.0,
#  'i_Denmark': 0.0,
#  'i_Afghanistan': 0.0,
#  'i_Dem. Rep. of the Congo': 0.0,
#  'i_Azerbaijan': 0.0,
#  'i_Mexico': 0.0,
#  'i_Jordan': 0.0,
#  'i_Yemen': 0.0,
#  'i_Indonesia': 0.0,
#  'i_USA': 0.0,
#  'i_Pakistan': 0.0,
#  'i_Viet Nam': 0.0,
#  'i_Slovakia': 0.0,
#  'i_Bahrain': 0.0,
#  'i_Israel': 0.0,
#  'i_Belgium': 0.0,
#  'i_Hungary': 0.0,
#  'i_Dominican Rep.': 0.0,
#  'i_Oman': 0.0,
#  'i_Slovenia': 0.0,
#  'i_Cyprus': 0.0,
#  'i_Czechia': 0.0,
#  'i_Mali': 0.0,
#  'i_Cameroon': 0.0,
#  'i_United Arab Emirates': 0.0,
#  'i_Serbia': 0.0,
#  'i_Greece': 0.0,
#  'i_Saudi Arabia': 0.0,
#  'i_Estonia': 0.0,
#  'i_Egypt': 0.0,
#  'i_New Zealand': 0.0,
#  'i_Russian Federation': 0.0,
#  'i_Bulgaria': 0.0,
#  'i_Colombia': 0.0,
#  'i_Tajikistan': 0.0,
#  'i_Canada': 0.0,
#  'i_Finland': 0.0,
#  'i_Guatemala': 0.0,
#  'i_Rep. of Korea': 0.0,
#  'i_Ethiopia': 0.0,
#  'i_Cambodia': 0.0,
#  'i_Costa Rica': 0.0,
#  'i_Tonga': 0.0,
#  'i_Austria': 0.0,
#  'i_Singapore': 0.0,
#  'i_Iran': 0.0,
#  'i_Poland': 0.0,
#  'i_Georgia': 0.0,
#  'i_Peru': 0.0,
#  'i_Zambia': 0.0,
#  'i_Nepal': 0.0,
#  'i_Thailand': 0.0,
#  'i_Malta': 0.0,
#  'i_French Polynesia': 0.0,
#  'i_Libya': 0.0,
#  'i_Panama': 0.0,
#  'i_Myanmar': 0.0,
#  'i_China': 0.0,
#  'i_Sweden': 0.0,
#  'i_Iraq': 0.0,
#  'i_Albania': 0.0,
#  'i_Uzbekistan': 0.0,
#  'i_Armenia': 0.0,
#  'i_Tunisia': 0.0,
#  'i_Netherlands': 0.0,
#  'i_Turkmenistan': 0.0,
#  'i_Bolivia (Plurinational State of)': 0.0,
#  'i_China, Hong Kong SAR': 0.0,
#  'i_Portugal': 0.0,
#  'i_Türkiye': 0.0,
#  "i_Lao People's Dem. Rep.": 0.0,
#  'i_Switzerland': 0.0,
#  'i_Namibia': 0.0,
#  'i_Norway': 0.0,
#  'i_Sierra Leone': 0.0,
#  'i_Morocco': 0.0,
#  'i_Italy': 0.0,
#  'i_Australia': 0.0,
#  'i_Spain': 0.0,
#  'i_Nigeria': 0.0,
#  'i_Ireland': 0.0,
#  'i_Latvia': 0.0,
#  'i_Chile': 0.0,
#  'i_Other Asia, nes': 0.0,
#  'i_South Africa': 0.0,
#  'i_France': 0.0,
#  'i_Niger': 0.0,
#  'i_Croatia': 0.0,
#  'i_Lithuania': 0.0,
#  'i_Argentina': 0.0,
#  'i_Romania': 0.0,
#  'i_United Kingdom': 0.0,
#  'i_Japan': 0.0,
#  'e_Oman': 1.4607843137254901,
#  'e_Poland': 1.4607843137254901,
#  'e_Other Asia, nes': 1.4607843137254901,
#  'e_United Arab Emirates': 1.4607843137254901,
#  'e_Br. Virgin Isds': 1.4607843137254901,
#  'e_Hungary': 1.4607843137254903,
#  'e_Uganda': 1.4607843137254901,
#  'e_Ireland': 1.4607843137254901,
#  'e_Ukraine': 1.4607843137254901,
#  'e_Australia': 1.4607843137254901,
#  'e_Namibia': 1.4607843137254901,
#  'e_Lebanon': 1.4607843137254901,
#  'e_Bulgaria': 1.4607843137254901,
#  'e_Portugal': 1.4607843137254901,
#  'e_Iraq': 1.4607843137254901,
#  'e_Albania': 1.4607843137254901,
#  'e_Palau': 1.4607843137254901,
#  'e_Türkiye': 1.4607843137254901,
#  'e_Denmark': 1.4607843137254901,
#  'e_Serbia': 1.4607843137254901,
#  'e_Japan': 1.4607843137254901,
#  'e_Malta': 1.4607843137254903,
#  'e_Armenia': 1.4607843137254901,
#  'e_Canada': 1.4607843137254901,
#  'e_Nigeria': 1.4607843137254901,
#  'e_Russian Federation': 1.4607843137254903,
#  'e_Nepal': 1.4607843137254901,
#  'e_Panama': 1.4607843137254901,
#  'e_Cambodia': 1.4607843137254901,
#  'e_Israel': 1.4607843137254901,
#  'e_Cyprus': 1.4607843137254903,
#  'e_Mexico': 1.4607843137254901,
#  'e_Myanmar': 1.4607843137254901,
#  'e_South Africa': 1.4607843137254901,
#  'e_Belgium': 1.4607843137254901,
#  'e_Yemen': 1.4607843137254901,
#  'e_Czechia': 1.4607843137254901,
#  'e_Brazil': 1.4607843137254901,
#  'e_Norway': 1.4607843137254901,
#  'e_Jordan': 1.4607843137254901,
#  'e_Rep. of Korea': 1.4607843137254903,
#  'e_Gibraltar': 1.4607843137254901,
#  'e_India': 1.4607843137254903,
#  'e_Nicaragua': 1.4607843137254901,
#  'e_Iceland': 1.4607843137254901,
#  'e_Bahrain': 1.4607843137254901,
#  'e_Thailand': 1.4607843137254901,
#  'e_Germany': 1.4607843137254901,
#  'e_Peru': 1.4607843137254901,
#  'e_Argentina': 1.4607843137254901,
#  'e_Latvia': 1.4607843137254901,
#  'e_Uzbekistan': 1.4607843137254901,
#  'e_Netherlands': 1.4607843137254903,
#  'e_Georgia': 1.4607843137254901,
#  'e_Dominican Rep.': 1.4607843137254901,
#  'e_Malaysia': 1.4607843137254901,
#  'e_New Zealand': 1.4607843137254901,
#  'e_Qatar': 1.4607843137254901,
#  'e_Sweden': 1.4607843137254903,
#  'e_Greece': 1.4607843137254901,
#  'e_France': 1.4607843137254903,
#  'e_Cayman Isds': 1.4607843137254901,
#  'e_Viet Nam': 1.4607843137254901,
#  'e_Mongolia': 1.4607843137254901,
#  'e_Morocco': 1.4607843137254901,
#  'e_Kuwait': 1.4607843137254903,
#  'e_Luxembourg': 1.4607843137254901,
#  'e_Slovakia': 1.4607843137254901,
#  'e_Guatemala': 1.4607843137254901,
#  'e_United Kingdom': 1.4607843137254903,
#  'e_Estonia': 1.4607843137254901,
#  'e_Singapore': 1.4607843137254903,
#  'e_Indonesia': 1.4607843137254901,
#  'e_China, Hong Kong SAR': 1.4607843137254901,
#  'e_Pakistan': 1.4607843137254901,
#  'e_Azerbaijan': 1.4607843137254901,
#  'e_Slovenia': 1.4607843137254901,
#  'e_China': 1.4607843137254901,
#  'e_Saudi Arabia': 1.4607843137254901,
#  'e_Finland': 1.4607843137254901,
#  'e_Costa Rica': 1.4607843137254901,
#  'e_Romania': 1.4607843137254901,
#  'e_Aruba': 1.4607843137254901,
#  'e_Spain': 1.4607843137254903,
#  'e_Switzerland': 1.4607843137254901,
#  'e_Croatia': 1.4607843137254901,
#  'e_Andorra': 1.4607843137254901,
#  'e_China, Macao SAR': 1.4607843137254901,
#  'e_Italy': 1.4607843137254901,
#  'e_USA': 1.4607843137254901,
#  'e_Lithuania': 1.4607843137254903,
#  'e_Chile': 1.4607843137254903,
#  'e_Austria': 1.4607843137254901,
#  'e_Bermuda': 1.4607843137254901,
#  'e_Maldives': 1.4607843137254901}

# %%
class weightedBipartiteGraph:
    '''
    Class for a number of functions for use on the bipartite network.
    '''
    
    def __init__(self, bipar_graph):
        self.bipar_graph = bipar_graph
    
    def maximum_cardinality_matching():
        '''
        
        '''
        
    def clustering_coefficient(self):
        
    def average_clustering(self):

# %%
# Returns the maximum cardinality matching of the bipartite graph (hopcroft_karp)
bpt.hopcroft_karp_matching(B, bipartite_exporters)

# Returns the maximum cardinality matching of the bipartite graph (eppstein_matching)
bpt.eppstein_matching(B, bipartite_exporters)

# Compute a bipartite clustering coefficient for nodes.
bpt.clustering(B, bipartite_exporters, mode='dot')

# Compute the average bipartite clustering coefficient.
bpt.average_clustering(B)

# Compute a bipartite clustering coefficient for nodes.
bpt.latapy_clustering(B)

# Compute the bipartite clustering of G.
# Robins and Alexander [1] defined bipartite clustering coefficient as four times the number of four cycles C_4 divided by the number of three paths L_3 in a bipartite graph:
bpt.robins_alexander_clustering(B)

# Computes the node redundancy coefficients for the nodes in the bipartite graph G.
#bpt.node_redundancy(B)

# Compute the closeness centrality for nodes in a bipartite network.
bpt.closeness_centrality(B, bipartite_exporters)

# Compute the degree centrality for nodes in a bipartite network.
bpt.degree_centrality(B, bipartite_exporters)

# Compute betweenness centrality for nodes in a bipartite network.
# Betweenness centrality of a node v is the sum of the fraction of all-pairs shortest paths that pass through v.
bpt.betweenness_centrality(B, bipartite_exporters)
# Out:
# {'e_Germany': 0.0,
#  'i_Afghanistan': 0.0,
#  'e_Ireland': 0.0,
#  'e_United Kingdom': 0.0,
#  'e_USA': 0.0,
#  'e_Switzerland': 0.0,
#  'i_Albania': 0.0,
#  'i_Algeria': 0.0,
#  'i_Angola': 0.0,
#  'e_France': 0.0,
#  'i_Argentina': 0.0,
#  'e_Hungary': 0.0,
#  'i_Armenia': 0.0,
#  'e_Finland': 0.0,
#  'i_Australia': 0.0,
#  'e_Italy': 0.0,
#  'e_Netherlands': 0.0,
#  'e_New Zealand': 0.0,
#  'e_Argentina': 0.0,
#  'i_Austria': 0.0,
#  'e_Australia': 0.0,
#  'e_Belgium': 0.0,
#  'e_Bulgaria': 0.0,
#  'e_Canada': 0.0,
#  'e_China': 0.0,
#  'e_Croatia': 0.0,
#  'e_Cyprus': 0.0,
#  'e_Czechia': 0.0,
#  'e_Denmark': 0.0,
#  'e_Estonia': 0.0,
#  'e_Greece': 0.0,
#  'e_China, Hong Kong SAR': 0.0,
#  'e_Israel': 0.0,
#  'e_Japan': 0.0,
#  'e_Rep. of Korea': 0.0,
#  'e_Lithuania': 0.0,
#  'e_Luxembourg': 0.0,
#  'e_Other Asia, nes': 0.0,
#  'e_Norway': 0.0,
#  'e_Poland': 0.0,
#  'e_Portugal': 0.0,
#  'e_Romania': 0.0,
#  'e_Russian Federation': 0.0,
#  'e_India': 0.0,
#  'e_Slovakia': 0.0,
#  'e_Slovenia': 0.0,
#  'e_Spain': 0.0,
#  'e_Sweden': 0.0,
#  'e_Türkiye': 0.0,
#  'i_Azerbaijan': 0.0,
#  'i_Bahrain': 0.0,
#  'i_Belgium': 0.0,
#  'e_Austria': 0.0,
#  'e_Cayman Isds': 0.0,
#  'e_Chile': 0.0,
#  'e_Mexico': 0.0,
#  'e_Qatar': 0.0,
#  'e_Singapore': 0.0,
#  'e_Thailand': 0.0,
#  'e_United Arab Emirates': 0.0,
#  'i_Bolivia (Plurinational State of)': 0.0,
#  'i_Brazil': 0.0,
#  'e_Malta': 0.0,
#  'e_Panama': 0.0,
#  'i_Bulgaria': 0.0,
#  'i_Cambodia': 0.0,
#  'i_Cameroon': 0.0,
#  'i_Canada': 0.0,
#  'i_Chile': 0.0,
#  'i_China': 0.0,
#  'e_Cambodia': 0.0,
#  'e_Lebanon': 0.0,
#  'e_China, Macao SAR': 0.0,
#  'e_Malaysia': 0.0,
#  'e_Pakistan': 0.0,
#  'e_South Africa': 0.0,
#  'i_China, Hong Kong SAR': 0.0,
#  'i_Colombia': 0.0,
#  'i_Costa Rica': 0.0,
#  'i_Croatia': 0.0,
#  'i_Cyprus': 0.0,
#  'i_Czechia': 0.0,
#  'i_Dem. Rep. of the Congo': 0.0,
#  'i_Denmark': 0.0,
#  'i_Dominican Rep.': 0.0,
#  'i_Egypt': 0.0,
#  'i_Estonia': 0.0,
#  'i_Ethiopia': 0.0,
#  'i_Finland': 0.0,
#  'e_Andorra': 0.0,
#  'i_France': 0.0,
#  'e_Brazil': 0.0,
#  'e_Guatemala': 0.0,
#  'e_Indonesia': 0.0,
#  'e_Kuwait': 0.0,
#  'e_Morocco': 0.0,
#  'e_Oman': 0.0,
#  'e_Saudi Arabia': 0.0,
#  'e_Viet Nam': 0.0,
#  'i_French Polynesia': 0.0,
#  'i_Georgia': 0.0,
#  'i_Germany': 0.0,
#  'e_Georgia': 0.0,
#  'e_Ukraine': 0.0,
#  'i_Greece': 0.0,
#  'i_Guatemala': 0.0,
#  'i_Hungary': 0.0,
#  'i_India': 0.0,
#  'i_Indonesia': 0.0,
#  'i_Iran': 0.0,
#  'i_Iraq': 0.0,
#  'i_Ireland': 0.0,
#  'i_Israel': 0.0,
#  'i_Italy': 0.0,
#  'i_Jamaica': 0.0,
#  'i_Japan': 0.0,
#  'i_Jordan': 0.0,
#  'i_Kenya': 0.0,
#  "i_Lao People's Dem. Rep.": 0.0,
#  'i_Latvia': 0.0,
#  'i_Lebanon': 0.0,
#  'i_Libya': 0.0,
#  'i_Lithuania': 0.0,
#  'i_Luxembourg': 0.0,
#  'i_Madagascar': 0.0,
#  'i_Mali': 0.0,
#  'i_Malta': 0.0,
#  'i_Mexico': 0.0,
#  'i_Morocco': 0.0,
#  'i_Myanmar': 0.0,
#  'i_Namibia': 0.0,
#  'i_Nepal': 0.0,
#  'i_Netherlands': 0.0,
#  'i_New Zealand': 0.0,
#  'i_Niger': 0.0,
#  'i_Nigeria': 0.0,
#  'i_Norway': 0.0,
#  'i_Oman': 0.0,
#  'i_Other Asia, nes': 0.0,
#  'i_Pakistan': 0.0,
#  'i_Panama': 0.0,
#  'i_Papua New Guinea': 0.0,
#  'i_Peru': 0.0,
#  'i_Philippines': 0.0,
#  'i_Poland': 0.0,
#  'i_Portugal': 0.0,
#  'e_Iceland': 0.0,
#  'i_Rep. of Korea': 0.0,
#  'i_Romania': 0.0,
#  'i_Russian Federation': 0.0,
#  'i_Saudi Arabia': 0.0,
#  'i_Serbia': 0.0,
#  'i_Sierra Leone': 0.0,
#  'i_Singapore': 0.0,
#  'i_Slovakia': 0.0,
#  'i_Slovenia': 0.0,
#  'i_South Africa': 0.0,
#  'e_Namibia': 0.0,
#  'i_Spain': 0.0,
#  'e_Costa Rica': 0.0,
#  'e_Iraq': 0.0,
#  'i_Sri Lanka': 0.0,
#  'i_Suriname': 0.0,
#  'i_Sweden': 0.0,
#  'i_Switzerland': 0.0,
#  'e_Br. Virgin Isds': 0.0,
#  'e_Latvia': 0.0,
#  'i_Syria': 0.0,
#  'i_Tajikistan': 0.0,
#  'i_Thailand': 0.0,
#  'i_Tonga': 0.0,
#  'i_Tunisia': 0.0,
#  'i_Turkmenistan': 0.0,
#  'i_Türkiye': 0.0,
#  'i_USA': 0.0,
#  'e_Armenia': 0.0,
#  'e_Bermuda': 0.0,
#  'e_Dominican Rep.': 0.0,
#  'e_Maldives': 0.0,
#  'e_Nepal': 0.0,
#  'e_Aruba': 0.0,
#  'e_Nigeria': 0.0,
#  'e_Peru': 0.0,
#  'e_Serbia': 0.0,
#  'e_Uzbekistan': 0.0,
#  'i_Ukraine': 0.0,
#  'i_United Arab Emirates': 0.0,
#  'e_Albania': 0.0,
#  'i_United Kingdom': 0.0,
#  'e_Azerbaijan': 0.0,
#  'e_Bahrain': 0.0,
#  'e_Myanmar': 0.0,
#  'e_Gibraltar': 0.0,
#  'e_Jordan': 0.0,
#  'e_Mongolia': 0.0,
#  'e_Nicaragua': 0.0,
#  'e_Palau': 0.0,
#  'e_Uganda': 0.0,
#  'e_Yemen': 0.0,
#  'i_Uruguay': 0.0,
#  'i_Uzbekistan': 0.0,
#  'i_Venezuela': 0.0,
#  'i_Viet Nam': 0.0,
#  'i_Yemen': 0.0,
#  'i_Zambia': 0.0}

# %%
# TO BE IMPLEMENTED
bpt.biadjacency_matrix(B)


# No attempt is made to check that the input graph is bipartite.

# For directed bipartite graphs only successors are considered as neighbors. 
# To obtain an adjacency matrix with ones (or weight values) for both predecessors and successors 
# you have to generate two biadjacency matrices where the rows of one of them are the columns of the other, 
# and then add one to the transpose of the other.

# %%
len(B.nodes())
# Out:
# 205

# %%
# We can save the different connected subnetworks as generator sets of nodes.
component_test = nx.weakly_connected_components(B)

# Our largest connected network can be found like this - Right now it returns all 126 nodes?? How come
largest_cc = max(nx.weakly_connected_components(B), key=len)
len(largest_cc)
# Out:
# 205

# %%
bpt.density(B,bipartite_exporters)
bpt.density(B, bipartite_importers)
# Out:
# 0.04555023923444976

# %%
# How to visualise a bipartite set (Should use a smaller sample)

l, r = nx.bipartite.sets(B)
pos = {}

# Update position for node from each group
pos.update((node, (1, index)) for index, node in enumerate(l))
pos.update((node, (2, index)) for index, node in enumerate(r))

nx.draw(B, pos=pos, with_labels = True)
plt.show()

# %%
# Node degree centrality
node_centrality_tuple_list, max_node_centrality = G_graph_test._closeness_centrality()
avg_neighbor_deg_tuple, max_avg_neighbor_deg = G_graph_test._average_neighbor_degree()
between_centr_tuple, max_between_centr = G_graph_test._betweenness_centrality()
clust_coe_tup, maxdic_clust = G_graph_test._clustering_coefficient()
longest_path = G_graph_test._maximum_shortest_path()

print(f'Our maximum node centrality is: {max_node_centrality}')
print()
print(f'Our maximum average neighbor degree nodes are: {list(max_avg_neighbor_deg.keys())} and they have value {list(max_avg_neighbor_deg.values())[0]}')
print()
print(f'Our maximum betweenness centrality node is: {max_between_centr}')
print()
print(f'Our maximum clustering coefficient nodes are: {list(maxdic_clust.keys())} and they have value {list(maxdic_clust.values())[0]}')
print()
print(f'Our longest path in the network is: {longest_path}')
# Out:
# Our maximum node centrality is: ('e_USA', 0.39705882352941174)
#
# Our maximum average neighbor degree nodes are: ['e_Albania', 'e_Andorra', 'e_Argentina', 'e_Armenia', 'e_Aruba', 'e_Australia', 'e_Austria', 'e_Azerbaijan', 'e_Bahrain', 'e_Belgium', 'e_Bermuda', 'e_Br. Virgin Isds', 'e_Brazil', 'e_Bulgaria', 'e_Cambodia', 'e_Canada', 'e_Cayman Isds', 'e_Chile', 'e_China', 'e_China, Hong Kong SAR', 'e_China, Macao SAR', 'e_Costa Rica', 'e_Croatia', 'e_Cyprus', 'e_Czechia', 'e_Denmark', 'e_Dominican Rep.', 'e_Estonia', 'e_Finland', 'e_France', 'e_Georgia', 'e_Germany', 'e_Gibraltar', 'e_Greece', 'e_Guatemala', 'e_Hungary', 'e_Iceland', 'e_India', 'e_Indonesia', 'e_Iraq', 'e_Ireland', 'e_Israel', 'e_Italy', 'e_Japan', 'e_Jordan', 'e_Kuwait', 'e_Latvia', 'e_Lebanon', 'e_Lithuania', 'e_Luxembourg', 'e_Malaysia', 'e_Maldives', 'e_Malta', 'e_Mexico', 'e_Mongolia', 'e_Morocco', 'e_Myanmar', 'e_Namibia', 'e_Nepal', 'e_Netherlands', 'e_New Zealand', 'e_Nicaragua', 'e_Nigeria', 'e_Norway', 'e_Oman', 'e_Other Asia, nes', 'e_Pakistan', 'e_Palau', 'e_Panama', 'e_Peru', 'e_Poland', 'e_Portugal', 'e_Qatar', 'e_Rep. of Korea', 'e_Romania', 'e_Russian Federation', 'e_Saudi Arabia', 'e_Serbia', 'e_Singapore', 'e_Slovakia', 'e_Slovenia', 'e_South Africa', 'e_Spain', 'e_Sweden', 'e_Switzerland', 'e_Thailand', 'e_Türkiye', 'e_USA', 'e_Uganda', 'e_Ukraine', 'e_United Arab Emirates', 'e_United Kingdom', 'e_Uzbekistan', 'e_Viet Nam', 'e_Yemen', 'i_Afghanistan', 'i_Albania', 'i_Algeria', 'i_Angola', 'i_Argentina', 'i_Armenia', 'i_Australia', 'i_Austria', 'i_Azerbaijan', 'i_Bahrain', 'i_Belgium', 'i_Bolivia (Plurinational State of)', 'i_Brazil', 'i_Bulgaria', 'i_Cambodia', 'i_Cameroon', 'i_Canada', 'i_Chile', 'i_China', 'i_China, Hong Kong SAR', 'i_Colombia', 'i_Costa Rica', 'i_Croatia', 'i_Cyprus', 'i_Czechia', 'i_Dem. Rep. of the Congo', 'i_Denmark', 'i_Dominican Rep.', 'i_Egypt', 'i_Estonia', 'i_Ethiopia', 'i_Finland', 'i_France', 'i_French Polynesia', 'i_Georgia', 'i_Germany', 'i_Greece', 'i_Guatemala', 'i_Hungary', 'i_India', 'i_Indonesia', 'i_Iran', 'i_Iraq', 'i_Ireland', 'i_Israel', 'i_Italy', 'i_Jamaica', 'i_Japan', 'i_Jordan', 'i_Kenya', "i_Lao People's Dem. Rep.", 'i_Latvia', 'i_Lebanon', 'i_Libya', 'i_Lithuania', 'i_Luxembourg', 'i_Madagascar', 'i_Mali', 'i_Malta', 'i_Mexico', 'i_Morocco', 'i_Myanmar', 'i_Namibia', 'i_Nepal', 'i_Netherlands', 'i_New Zealand', 'i_Niger', 'i_Nigeria', 'i_Norway', 'i_Oman', 'i_Other Asia, nes', 'i_Pakistan', 'i_Panama', 'i_Papua New Guinea', 'i_Peru', 'i_Philippines', 'i_Poland', 'i_Portugal', 'i_Rep. of Korea', 'i_Romania', 'i_Russian Federation', 'i_Saudi Arabia', 'i_Serbia', 'i_Sierra Leone', 'i_Singapore', 'i_Slovakia', 'i_Slovenia', 'i_South Africa', 'i_Spain', 'i_Sri Lanka', 'i_Suriname', 'i_Sweden', 'i_Switzerland', 'i_Syria', 'i_Tajikistan', 'i_Thailand', 'i_Tonga', 'i_Tunisia', 'i_Turkmenistan', 'i_Türkiye', 'i_USA', 'i_Ukraine', 'i_United Arab Emirates', 'i_United Kingdom', 'i_Uruguay', 'i_Uzbekistan', 'i_Venezuela', 'i_Viet Nam', 'i_Yemen', 'i_Zambia'] and they have value 0.0
#
# Our maximum betweenness centrality node is: (0, 0)
#
# Our maximum clustering coefficient nodes are: ['e_Albania', 'e_Andorra', 'e_Argentina', 'e_Armenia', 'e_Aruba', 'e_Australia', 'e_Austria', 'e_Azerbaijan', 'e_Bahrain', 'e_Belgium', 'e_Bermuda', 'e_Br. Virgin Isds', 'e_Brazil', 'e_Bulgaria', 'e_Cambodia', 'e_Canada', 'e_Cayman Isds', 'e_Chile', 'e_China', 'e_China, Hong Kong SAR', 'e_China, Macao SAR', 'e_Costa Rica', 'e_Croatia', 'e_Cyprus', 'e_Czechia', 'e_Denmark', 'e_Dominican Rep.', 'e_Estonia', 'e_Finland', 'e_France', 'e_Georgia', 'e_Germany', 'e_Gibraltar', 'e_Greece', 'e_Guatemala', 'e_Hungary', 'e_Iceland', 'e_India', 'e_Indonesia', 'e_Iraq', 'e_Ireland', 'e_Israel', 'e_Italy', 'e_Japan', 'e_Jordan', 'e_Kuwait', 'e_Latvia', 'e_Lebanon', 'e_Lithuania', 'e_Luxembourg', 'e_Malaysia', 'e_Maldives', 'e_Malta', 'e_Mexico', 'e_Mongolia', 'e_Morocco', 'e_Myanmar', 'e_Namibia', 'e_Nepal', 'e_Netherlands', 'e_New Zealand', 'e_Nicaragua', 'e_Nigeria', 'e_Norway', 'e_Oman', 'e_Other Asia, nes', 'e_Pakistan', 'e_Palau', 'e_Panama', 'e_Peru', 'e_Poland', 'e_Portugal', 'e_Qatar', 'e_Rep. of Korea', 'e_Romania', 'e_Russian Federation', 'e_Saudi Arabia', 'e_Serbia', 'e_Singapore', 'e_Slovakia', 'e_Slovenia', 'e_South Africa', 'e_Spain', 'e_Sweden', 'e_Switzerland', 'e_Thailand', 'e_Türkiye', 'e_USA', 'e_Uganda', 'e_Ukraine', 'e_United Arab Emirates', 'e_United Kingdom', 'e_Uzbekistan', 'e_Viet Nam', 'e_Yemen', 'i_Afghanistan', 'i_Albania', 'i_Algeria', 'i_Angola', 'i_Argentina', 'i_Armenia', 'i_Australia', 'i_Austria', 'i_Azerbaijan', 'i_Bahrain', 'i_Belgium', 'i_Bolivia (Plurinational State of)', 'i_Brazil', 'i_Bulgaria', 'i_Cambodia', 'i_Cameroon', 'i_Canada', 'i_Chile', 'i_China', 'i_China, Hong Kong SAR', 'i_Colombia', 'i_Costa Rica', 'i_Croatia', 'i_Cyprus', 'i_Czechia', 'i_Dem. Rep. of the Congo', 'i_Denmark', 'i_Dominican Rep.', 'i_Egypt', 'i_Estonia', 'i_Ethiopia', 'i_Finland', 'i_France', 'i_French Polynesia', 'i_Georgia', 'i_Germany', 'i_Greece', 'i_Guatemala', 'i_Hungary', 'i_India', 'i_Indonesia', 'i_Iran', 'i_Iraq', 'i_Ireland', 'i_Israel', 'i_Italy', 'i_Jamaica', 'i_Japan', 'i_Jordan', 'i_Kenya', "i_Lao People's Dem. Rep.", 'i_Latvia', 'i_Lebanon', 'i_Libya', 'i_Lithuania', 'i_Luxembourg', 'i_Madagascar', 'i_Mali', 'i_Malta', 'i_Mexico', 'i_Morocco', 'i_Myanmar', 'i_Namibia', 'i_Nepal', 'i_Netherlands', 'i_New Zealand', 'i_Niger', 'i_Nigeria', 'i_Norway', 'i_Oman', 'i_Other Asia, nes', 'i_Pakistan', 'i_Panama', 'i_Papua New Guinea', 'i_Peru', 'i_Philippines', 'i_Poland', 'i_Portugal', 'i_Rep. of Korea', 'i_Romania', 'i_Russian Federation', 'i_Saudi Arabia', 'i_Serbia', 'i_Sierra Leone', 'i_Singapore', 'i_Slovakia', 'i_Slovenia', 'i_South Africa', 'i_Spain', 'i_Sri Lanka', 'i_Suriname', 'i_Sweden', 'i_Switzerland', 'i_Syria', 'i_Tajikistan', 'i_Thailand', 'i_Tonga', 'i_Tunisia', 'i_Turkmenistan', 'i_Türkiye', 'i_USA', 'i_Ukraine', 'i_United Arab Emirates', 'i_United Kingdom', 'i_Uruguay', 'i_Uzbekistan', 'i_Venezuela', 'i_Viet Nam', 'i_Yemen', 'i_Zambia'] and they have value 0
#
# Our longest path in the network is: 1
