# %%
# TO DO: 
# Convert the network into a bipartite/pseudo-bipartite network, between importers on one side and exporters on the other
# Already doing this we would have done a lot of network analysis and shown off a lot
# Then also include a previous years' network and we can do a comparison between the two

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import os

import glob

# %%
# Point to the 2022 BACI csv dataset
file_path = "/Users/zenrehda/Desktop/NAProject/BACI_HS22_Y2022_V202401b.csv"

# %%
# Our product code for historical artifacts, saved as a list if we want to include multiple product codes
product_codes = [970610]

# %%
# Read the CSV in chunks, ensuring the Multi-Index structure is preserved
filtered_data = pd.concat(
    chunk[chunk.index.get_level_values('k').isin(product_codes)] for chunk in pd.read_csv(
        file_path, chunksize=10000, index_col=[0, 1, 2, 3, 4, 5]  # Adjust this list to match your Multi-Index levels
    )
)

# %% [markdown]
# ### The codes for each index:
# 't' = year
#
# 'i' = exporter
#
# 'j' = importer
#
# 'k' = product
#
# 'v' = value
#
# 'q' = quantity

# %%
# DO NOT RUN YET - Code is created to work on a MultiIndex, so we have 0 columns. If we want columns, reset index below

# We reset the index to make sure the columns work as intended, as pandas currently treats this as a MultiIndex (complicado, no me gusta)
#filtered_data = filtered_data.reset_index()

# This will give us the clearly defined columns
#print(filtered_data.columns)

# %%
filtered_data
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2022, 4, 276, 970610, 1.759,         0.003), (2022, 4, 372, 970610, 36.632,         0.015), (2022, 4, 826, 970610, 33.359,         0.034), (2022, 4, 842, 970610, 3.823,         0.002), (2022, 8, 757, 970610, 2.589,         0.013), (2022, 12, 757, 970610, 14.555,         0.004), (2022, 24, 842, 970610, 367.979,         0.029), (2022, 31, 826, 970610, 24.165,         0.012), (2022, 31, 842, 970610, 214.325,         0.065), (2022, 32, 251, 970610, 3.313,         0.002), (2022, 32, 348, 970610, 0.192,            NA), (2022, 32, 842, 970610, 159.839,        40.315), (2022, 36, 246, 970610, 8.567,         0.002), (2022, 36, 276, 970610, 2.984,         0.002), (2022, 36, 372, 970610, 11.188,         0.004), (2022, 36, 380, 970610, 6.303,         0.014), (2022, 36, 528, 970610, 1.391,         0.022), (2022, 36, 554, 970610, 22.597,            NA), (2022, 36, 757, 970610, 1.732,         0.003), (2022, 36, 826, 970610, 519.759,         0.988), (2022, 36, 842, 970610, 46.462,         0.049), (2022, 40, 32, 970610, 8.951,         0.250), (2022, 40, 36, 970610, 62.233,         0.088), (2022, 40, 56, 970610, 2.92,         0.011), (2022, 40, 100, 970610, 0.398,         0.001), (2022, 40, 124, 970610, 72.395,         0.021), (2022, 40, 156, 970610, 233.325,         0.094), (2022, 40, 191, 970610, 1.885,         0.006), (2022, 40, 196, 970610, 1.237,         0.004), (2022, 40, 203, 970610, 7.702,         0.018), (2022, 40, 208, 970610, 1.531,         0.001), (2022, 40, 233, 970610, 0.31,         0.002), (2022, 40, 246, 970610, 0.2,         0.001), (2022, 40, 251, 970610, 125.54,         0.169), (2022, 40, 276, 970610, 83.202,         0.078), (2022, 40, 300, 970610, 1.869,         0.005), (2022, 40, 344, 970610, 1143.926,         1.112), (2022, 40, 348, 970610, 13.871,         0.026), (2022, 40, 372, 970610, 4.08,         0.011), (2022, 40, 376, 970610, 56.432,         0.002), (2022, 40, 380, 970610, 36.132,         0.045), (2022, 40, 392, 970610, 254.361,         0.031), (2022, 40, 410, 970610, 1.028,         0.004), (2022, 40, 440, 970610, 0.164,         0.001), (2022, 40, 442, 970610, 0.269,         0.001), (2022, 40, 490, 970610, 231.12,         0.066), (2022, 40, 528, 970610, 13.628,         0.022), (2022, 40, 579, 970610, 0.776,         0.009), (2022, 40, 616, 970610, 5.542,         0.020), (2022, 40, 620, 970610, 3.874,         0.011), (2022, 40, 642, 970610, 2.847,         0.011), (2022, 40, 643, 970610, 8.62,         0.006), (2022, 40, 699, 970610, 34.536,         0.095), (2022, 40, 703, 970610, 1.873,         0.008), (2022, 40, 705, 970610, 3.686,         0.004), (2022, 40, 724, 970610, 6.31,         0.018), (2022, 40, 752, 970610, 0.805,         0.003), (2022, 40, 757, 970610, 444.043,         0.719), (2022, 40, 792, 970610, 4.16,         0.001), (2022, 40, 826, 970610, 828.397,         0.351), (2022, 40, 842, 970610, 1571.229,         4.307), (2022, 48, 826, 970610, 3.817,         0.001), (2022, 51, 757, 970610, 31.668,         0.009), (2022, 51, 826, 970610, 362.431,         0.001), (2022, 56, 36, 970610, 146.088,         0.086), (2022, 56, 40, 970610, 3.159,         0.002), (2022, 56, 124, 970610, 39.857,         0.158), (2022, 56, 136, 970610, 1.895,         0.004), (2022, 56, 152, 970610, 0.181,         0.002), (2022, 56, 156, 970610, 1.363,         0.002), (2022, 56, 251, 970610, 506.858,         0.711), (2022, 56, 276, 970610, 129.552,         0.112), (2022, 56, 344, 970610, 105.425,         0.060), (2022, 56, 376, 970610, 48.595,         0.428), (2022, 56, 380, 970610, 80.096,         0.001), (2022, 56, 392, 970610, 49.251,         0.006), (2022, 56, 410, 970610, 11.427,         0.012), (2022, 56, 442, 970610, 0.16,         0.012), (2022, 56, 484, 970610, 2.582,         0.003), (2022, 56, 490, 970610, 3.218,         0.004), (2022, 56, 528, 970610, 3.834,         0.008), (2022, 56, 554, 970610, 1.264,         0.001), (2022, 56, 579, 970610, 1.085,         0.001), (2022, 56, 634, 970610, 24.747,         0.900), (2022,  ...
#
# [952 rows x 0 columns]

# %%
from collections import defaultdict

# Initialize a dictionary to store edges with weights
edges = defaultdict(float)

# Iterate through the datasets_by_exporter dictionary
for exporter, df in datasets_by_exporter.items():
    # Iterate through each row in the DataFrame
    for idx, row in df.iterrows():
        # Extract importer (j), exporter (i), and transaction value (v)
        exporter = idx[1]  # 'i' level from MultiIndex
        importer = idx[2]  # 'j' level from MultiIndex
        value = idx[4]   # 'v' column value

        # Add the value to the corresponding (importer, exporter) edge
        edges[(exporter, importer)] += value

# Convert defaultdict back to a normal dictionary (optional)
edges = dict(edges)

print(edges)
# Out:
# {(4, 276): 1.759, (4, 372): 36.632, (4, 826): 33.359, (4, 842): 3.823, (8, 757): 2.589, (12, 757): 14.555, (24, 842): 367.979, (31, 826): 24.165, (31, 842): 214.325, (32, 251): 3.313, (32, 348): 0.192, (32, 842): 159.839, (36, 246): 8.567, (36, 276): 2.984, (36, 372): 11.188, (36, 380): 6.303, (36, 528): 1.391, (36, 554): 22.597, (36, 757): 1.732, (36, 826): 519.759, (36, 842): 46.462, (40, 32): 8.951, (40, 36): 62.233, (40, 56): 2.92, (40, 100): 0.398, (40, 124): 72.395, (40, 156): 233.325, (40, 191): 1.885, (40, 196): 1.237, (40, 203): 7.702, (40, 208): 1.531, (40, 233): 0.31, (40, 246): 0.2, (40, 251): 125.54, (40, 276): 83.202, (40, 300): 1.869, (40, 344): 1143.926, (40, 348): 13.871, (40, 372): 4.08, (40, 376): 56.432, (40, 380): 36.132, (40, 392): 254.361, (40, 410): 1.028, (40, 440): 0.164, (40, 442): 0.269, (40, 490): 231.12, (40, 528): 13.628, (40, 579): 0.776, (40, 616): 5.542, (40, 620): 3.874, (40, 642): 2.847, (40, 643): 8.62, (40, 699): 34.536, (40, 703): 1.873, (40, 705): 3.686, (40, 724): 6.31, (40, 752): 0.805, (40, 757): 444.043, (40, 792): 4.16, (40, 826): 828.397, (40, 842): 1571.229, (48, 826): 3.817, (51, 757): 31.668, (51, 826): 362.431, (56, 36): 146.088, (56, 40): 3.159, (56, 124): 39.857, (56, 136): 1.895, (56, 152): 0.181, (56, 156): 1.363, (56, 251): 506.858, (56, 276): 129.552, (56, 344): 105.425, (56, 376): 48.595, (56, 380): 80.096, (56, 392): 49.251, (56, 410): 11.427, (56, 442): 0.16, (56, 484): 2.582, (56, 490): 3.218, (56, 528): 3.834, (56, 554): 1.264, (56, 579): 1.085, (56, 634): 24.747, (56, 643): 16.921, (56, 699): 26.326, (56, 702): 9114.774, (56, 757): 259.432, (56, 764): 1.369, (56, 784): 0.65, (56, 792): 6.965, (56, 826): 2275.506, (56, 842): 7288.249, (68, 276): 3.637, (68, 842): 22.701, (76, 36): 12.121, (76, 124): 4.719, (76, 251): 878.372, (76, 344): 0.006, (76, 470): 0.055, (76, 579): 1.348, (76, 591): 0.043, (76, 702): 0.058, (76, 757): 0.856, (76, 826): 3.985, (76, 842): 13.641, (100, 528): 0.225, (100, 842): 26.423, (104, 702): 64.821, (104, 842): 10.754, (116, 124): 4.473, (116, 842): 51.343, (120, 842): 494.682, (124, 40): 6.531, (124, 56): 1.673, (124, 156): 22.358, (124, 203): 0.637, (124, 208): 0.187, (124, 251): 7.324, (124, 276): 0.769, (124, 344): 21.513, (124, 372): 0.377, (124, 380): 1.02, (124, 392): 31.744, (124, 528): 0.615, (124, 724): 4.289, (124, 752): 0.19, (124, 757): 24.541, (124, 826): 396.453, (124, 842): 2972.989, (144, 276): 0.032, (144, 842): 290.092, (152, 36): 11.831, (152, 251): 12.748, (152, 842): 1062.403, (156, 36): 1584.708, (156, 40): 0.275, (156, 116): 5850.0, (156, 124): 1272.767, (156, 152): 21.004, (156, 203): 1.773, (156, 246): 3.897, (156, 251): 5.665, (156, 276): 55.571, (156, 344): 70115.621, (156, 372): 196.718, (156, 380): 33.887, (156, 392): 4313.213, (156, 410): 1.359, (156, 422): 9395.0, (156, 440): 0.345, (156, 446): 503.505, (156, 458): 9.553, (156, 490): 10.103, (156, 528): 4995.008, (156, 554): 1.53, (156, 579): 5.852, (156, 586): 7820.0, (156, 620): 13.679, (156, 702): 272.753, (156, 703): 0.764, (156, 710): 0.638, (156, 724): 3.224, (156, 752): 6.411, (156, 757): 738.303, (156, 784): 1339.808, (156, 826): 2289.497, (156, 842): 13556.478, (170, 842): 3560.319, (180, 724): 8.03, (180, 842): 141.776, (188, 757): 7.91, (188, 842): 22.984, (191, 36): 34.102, (191, 528): 0.352, (196, 528): 0.007, (196, 757): 0.325, (196, 826): 0.011, (196, 842): 70.626, (203, 40): 0.819, (203, 56): 1.077, (203, 208): 0.214, (203, 251): 1.868, (203, 276): 9.791, (203, 300): 0.734, (203, 376): 1.987, (203, 380): 0.657, (203, 410): 0.75, (203, 442): 0.024, (203, 528): 3.128, (203, 579): 0.151, (203, 616): 21.09, (203, 620): 0.312, (203, 703): 0.339, (203, 724): 0.554, (203, 826): 81.354, (203, 842): 169.203, (208, 36): 5.468, (208, 124): 22.132, (208, 156): 121.487, (208, 251): 7.086, (208, 344): 865.527, (208, 376): 0.986, (208, 528): 3.435, (208, 579): 33.095, (208, 702): 1.198, (208, 757): 4.817, (208, 784): 6.009, (208, 826): 9156.815, (208, 842):  ...

# %%
import networkx as nx

# Create an empty directed graph
B = nx.DiGraph()

# Add edges with weights
for (importer, exporter), weight in edges.items():
    B.add_edge(exporter, importer, weight=weight)


def graph_info(G):
    info = (
        f"Graph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.\n"
        f"Is directed: {G.is_directed()}\n"
        f"Average degree: {sum(dict(G.degree()).values()) / G.number_of_nodes():.2f}"
    )
    return info

print(graph_info(B))
# Out:
# Graph with 126 nodes and 952 edges.
# Is directed: True
# Average degree: 15.11

# %%
# Draw the graph (this may not work well for very large graphs)
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(B)  # positions for all nodes
nx.draw_networkx_nodes(B, pos, node_size=700)
nx.draw_networkx_edges(B, pos, arrowstyle='-|>', arrowsize=20)
nx.draw_networkx_labels(B, pos, font_size=10)
edge_labels = nx.get_edge_attributes(B, 'weight')
nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)

plt.title("Imports/Exports Directed Graph")
plt.show()

# %%
# Create a dictionary to hold DataFrames for each unique `i`
datasets_by_exporter = {exporter: data for exporter, data in filtered_data.groupby(level='i')}


# Optionally, you can save each DataFrame to a CSV file if needed
for exporter, df in datasets_by_exporter.items():
    output_file = f"export_csv/dataset_for_exporter_{exporter}.csv"  # Modify the filename as needed
    df.to_csv(output_file)  # Save to CSV
    print(f"Saved dataset for exporter {exporter} to {output_file}")
# Out:
# Saved dataset for exporter 4 to export_csv/dataset_for_exporter_4.csv
# Saved dataset for exporter 8 to export_csv/dataset_for_exporter_8.csv
# Saved dataset for exporter 12 to export_csv/dataset_for_exporter_12.csv
# Saved dataset for exporter 24 to export_csv/dataset_for_exporter_24.csv
# Saved dataset for exporter 31 to export_csv/dataset_for_exporter_31.csv
# Saved dataset for exporter 32 to export_csv/dataset_for_exporter_32.csv
# Saved dataset for exporter 36 to export_csv/dataset_for_exporter_36.csv
# Saved dataset for exporter 40 to export_csv/dataset_for_exporter_40.csv
# Saved dataset for exporter 48 to export_csv/dataset_for_exporter_48.csv
# Saved dataset for exporter 51 to export_csv/dataset_for_exporter_51.csv
# Saved dataset for exporter 56 to export_csv/dataset_for_exporter_56.csv
# Saved dataset for exporter 68 to export_csv/dataset_for_exporter_68.csv
# Saved dataset for exporter 76 to export_csv/dataset_for_exporter_76.csv
# Saved dataset for exporter 100 to export_csv/dataset_for_exporter_100.csv
# Saved dataset for exporter 104 to export_csv/dataset_for_exporter_104.csv
# Saved dataset for exporter 116 to export_csv/dataset_for_exporter_116.csv
# Saved dataset for exporter 120 to export_csv/dataset_for_exporter_120.csv
# Saved dataset for exporter 124 to export_csv/dataset_for_exporter_124.csv
# Saved dataset for exporter 144 to export_csv/dataset_for_exporter_144.csv
# Saved dataset for exporter 152 to export_csv/dataset_for_exporter_152.csv
# Saved dataset for exporter 156 to export_csv/dataset_for_exporter_156.csv
# Saved dataset for exporter 170 to export_csv/dataset_for_exporter_170.csv
# Saved dataset for exporter 180 to export_csv/dataset_for_exporter_180.csv
# Saved dataset for exporter 188 to export_csv/dataset_for_exporter_188.csv
# Saved dataset for exporter 191 to export_csv/dataset_for_exporter_191.csv
# Saved dataset for exporter 196 to export_csv/dataset_for_exporter_196.csv
# Saved dataset for exporter 203 to export_csv/dataset_for_exporter_203.csv
# Saved dataset for exporter 208 to export_csv/dataset_for_exporter_208.csv
# Saved dataset for exporter 214 to export_csv/dataset_for_exporter_214.csv
# Saved dataset for exporter 231 to export_csv/dataset_for_exporter_231.csv
# Saved dataset for exporter 233 to export_csv/dataset_for_exporter_233.csv
# Saved dataset for exporter 246 to export_csv/dataset_for_exporter_246.csv
# Saved dataset for exporter 251 to export_csv/dataset_for_exporter_251.csv
# Saved dataset for exporter 258 to export_csv/dataset_for_exporter_258.csv
# Saved dataset for exporter 268 to export_csv/dataset_for_exporter_268.csv
# Saved dataset for exporter 276 to export_csv/dataset_for_exporter_276.csv
# Saved dataset for exporter 300 to export_csv/dataset_for_exporter_300.csv
# Saved dataset for exporter 320 to export_csv/dataset_for_exporter_320.csv
# Saved dataset for exporter 344 to export_csv/dataset_for_exporter_344.csv
# Saved dataset for exporter 348 to export_csv/dataset_for_exporter_348.csv
# Saved dataset for exporter 360 to export_csv/dataset_for_exporter_360.csv
# Saved dataset for exporter 364 to export_csv/dataset_for_exporter_364.csv
# Saved dataset for exporter 368 to export_csv/dataset_for_exporter_368.csv
# Saved dataset for exporter 372 to export_csv/dataset_for_exporter_372.csv
# Saved dataset for exporter 376 to export_csv/dataset_for_exporter_376.csv
# Saved dataset for exporter 380 to export_csv/dataset_for_exporter_380.csv
# Saved dataset for exporter 388 to export_csv/dataset_for_exporter_388.csv
# Saved dataset for exporter 392 to export_csv/dataset_for_exporter_392.csv
# Saved dataset for exporter 400 to export_csv/dataset_for_exporter_400.csv
# Saved dataset for exporter 404 to export_csv/dataset_for_exporter_404.csv
# Saved dataset for exporter 410 to export_csv/dataset_for_exporter_410.csv
# Saved dataset for exporter 418 to export_csv/dataset_for_exporter_418.csv
# Saved dataset for exporter 422 to export_csv/dataset_for_exporter_422.csv
# Saved dataset for exporter 428 to export_csv/dataset_for_exporter_428.csv
# Saved dataset for exporter 434 to export_csv/dataset_for_exporter_434.csv
# Saved dataset for exporter 440 to export_csv/dataset_for_exporter_440.csv
# Saved dataset for exporter 442 to export_csv/dataset_for_exporter_442.csv
# Saved dataset for exporter 450 to export_csv/dataset_for_exporter_450.csv
# Saved dataset for exporter 466 to export_csv/dataset_for_exporter_466.csv
# Saved dataset for exporter 470 to export_csv/dataset_for_exporter_470.csv
# Saved dataset for exporter 484 to export_csv/dataset_for_exporter_484.csv
# Saved dataset for exporter 490 to export_csv/dataset_for_exporter_490.csv
# Saved dataset for exporter 504 to export_csv/dataset_for_exporter_504.csv
# Saved dataset for exporter 512 to export_csv/dataset_for_exporter_512.csv
# Saved dataset for exporter 516 to export_csv/dataset_for_exporter_516.csv
# Saved dataset for exporter 524 to export_csv/dataset_for_exporter_524.csv
# Saved dataset for exporter 528 to export_csv/dataset_for_exporter_528.csv
# Saved dataset for exporter 554 to export_csv/dataset_for_exporter_554.csv
# Saved dataset for exporter 562 to export_csv/dataset_for_exporter_562.csv
# Saved dataset for exporter 566 to export_csv/dataset_for_exporter_566.csv
# Saved dataset for exporter 579 to export_csv/dataset_for_exporter_579.csv
# Saved dataset for exporter 586 to export_csv/dataset_for_exporter_586.csv
# Saved dataset for exporter 591 to export_csv/dataset_for_exporter_591.csv
# Saved dataset for exporter 598 to export_csv/dataset_for_exporter_598.csv
# Saved dataset for exporter 604 to export_csv/dataset_for_exporter_604.csv
# Saved dataset for exporter 608 to export_csv/dataset_for_exporter_608.csv
# Saved dataset for exporter 616 to export_csv/dataset_for_exporter_616.csv
# Saved dataset for exporter 620 to export_csv/dataset_for_exporter_620.csv
# Saved dataset for exporter 642 to export_csv/dataset_for_exporter_642.csv
# Saved dataset for exporter 643 to export_csv/dataset_for_exporter_643.csv
# Saved dataset for exporter 682 to export_csv/dataset_for_exporter_682.csv
# Saved dataset for exporter 688 to export_csv/dataset_for_exporter_688.csv
# Saved dataset for exporter 694 to export_csv/dataset_for_exporter_694.csv
# Saved dataset for exporter 699 to export_csv/dataset_for_exporter_699.csv
# Saved dataset for exporter 702 to export_csv/dataset_for_exporter_702.csv
# Saved dataset for exporter 703 to export_csv/dataset_for_exporter_703.csv
# Saved dataset for exporter 704 to export_csv/dataset_for_exporter_704.csv
# Saved dataset for exporter 705 to export_csv/dataset_for_exporter_705.csv
# Saved dataset for exporter 710 to export_csv/dataset_for_exporter_710.csv
# Saved dataset for exporter 724 to export_csv/dataset_for_exporter_724.csv
# Saved dataset for exporter 740 to export_csv/dataset_for_exporter_740.csv
# Saved dataset for exporter 752 to export_csv/dataset_for_exporter_752.csv
# Saved dataset for exporter 757 to export_csv/dataset_for_exporter_757.csv
# Saved dataset for exporter 760 to export_csv/dataset_for_exporter_760.csv
# Saved dataset for exporter 762 to export_csv/dataset_for_exporter_762.csv
# Saved dataset for exporter 764 to export_csv/dataset_for_exporter_764.csv
# Saved dataset for exporter 776 to export_csv/dataset_for_exporter_776.csv
# Saved dataset for exporter 784 to export_csv/dataset_for_exporter_784.csv
# Saved dataset for exporter 788 to export_csv/dataset_for_exporter_788.csv
# Saved dataset for exporter 792 to export_csv/dataset_for_exporter_792.csv
# Saved dataset for exporter 795 to export_csv/dataset_for_exporter_795.csv
# Saved dataset for exporter 804 to export_csv/dataset_for_exporter_804.csv
# Saved dataset for exporter 818 to export_csv/dataset_for_exporter_818.csv
# Saved dataset for exporter 826 to export_csv/dataset_for_exporter_826.csv
# Saved dataset for exporter 842 to export_csv/dataset_for_exporter_842.csv
# Saved dataset for exporter 858 to export_csv/dataset_for_exporter_858.csv
# Saved dataset for exporter 860 to export_csv/dataset_for_exporter_860.csv
# Saved dataset for exporter 862 to export_csv/dataset_for_exporter_862.csv
# Saved dataset for exporter 887 to export_csv/dataset_for_exporter_887.csv
# Saved dataset for exporter 894 to export_csv/dataset_for_exporter_894.csv

# %%
# Create a dictionary to hold DataFrames for each unique `i`
datasets_by_exporter = {exporter: data for exporter, data in filtered_data.groupby(level='i')}

# Create the output directory if it doesn't exist
output_dir = "export_csv"
os.makedirs(output_dir, exist_ok=True)  # Create the folder if it doesn't already exist

# Save each DataFrame to a CSV file
for exporter, df in datasets_by_exporter.items():
    output_file = os.path.join(output_dir, f"dataset_for_exporter_{exporter}.csv")  # Construct file path
    df.to_csv(output_file)  # Save to CSV
    print(f"Saved dataset for exporter {exporter} to {output_file}")
# Out:
# Saved dataset for exporter 4 to exporter_csv/dataset_for_exporter_4.csv
# Saved dataset for exporter 8 to exporter_csv/dataset_for_exporter_8.csv
# Saved dataset for exporter 12 to exporter_csv/dataset_for_exporter_12.csv
# Saved dataset for exporter 24 to exporter_csv/dataset_for_exporter_24.csv
# Saved dataset for exporter 31 to exporter_csv/dataset_for_exporter_31.csv
# Saved dataset for exporter 32 to exporter_csv/dataset_for_exporter_32.csv
# Saved dataset for exporter 36 to exporter_csv/dataset_for_exporter_36.csv
# Saved dataset for exporter 40 to exporter_csv/dataset_for_exporter_40.csv
# Saved dataset for exporter 48 to exporter_csv/dataset_for_exporter_48.csv
# Saved dataset for exporter 51 to exporter_csv/dataset_for_exporter_51.csv
# Saved dataset for exporter 56 to exporter_csv/dataset_for_exporter_56.csv
# Saved dataset for exporter 68 to exporter_csv/dataset_for_exporter_68.csv
# Saved dataset for exporter 76 to exporter_csv/dataset_for_exporter_76.csv
# Saved dataset for exporter 100 to exporter_csv/dataset_for_exporter_100.csv
# Saved dataset for exporter 104 to exporter_csv/dataset_for_exporter_104.csv
# Saved dataset for exporter 116 to exporter_csv/dataset_for_exporter_116.csv
# Saved dataset for exporter 120 to exporter_csv/dataset_for_exporter_120.csv
# Saved dataset for exporter 124 to exporter_csv/dataset_for_exporter_124.csv
# Saved dataset for exporter 144 to exporter_csv/dataset_for_exporter_144.csv
# Saved dataset for exporter 152 to exporter_csv/dataset_for_exporter_152.csv
# Saved dataset for exporter 156 to exporter_csv/dataset_for_exporter_156.csv
# Saved dataset for exporter 170 to exporter_csv/dataset_for_exporter_170.csv
# Saved dataset for exporter 180 to exporter_csv/dataset_for_exporter_180.csv
# Saved dataset for exporter 188 to exporter_csv/dataset_for_exporter_188.csv
# Saved dataset for exporter 191 to exporter_csv/dataset_for_exporter_191.csv
# Saved dataset for exporter 196 to exporter_csv/dataset_for_exporter_196.csv
# Saved dataset for exporter 203 to exporter_csv/dataset_for_exporter_203.csv
# Saved dataset for exporter 208 to exporter_csv/dataset_for_exporter_208.csv
# Saved dataset for exporter 214 to exporter_csv/dataset_for_exporter_214.csv
# Saved dataset for exporter 231 to exporter_csv/dataset_for_exporter_231.csv
# Saved dataset for exporter 233 to exporter_csv/dataset_for_exporter_233.csv
# Saved dataset for exporter 246 to exporter_csv/dataset_for_exporter_246.csv
# Saved dataset for exporter 251 to exporter_csv/dataset_for_exporter_251.csv
# Saved dataset for exporter 258 to exporter_csv/dataset_for_exporter_258.csv
# Saved dataset for exporter 268 to exporter_csv/dataset_for_exporter_268.csv
# Saved dataset for exporter 276 to exporter_csv/dataset_for_exporter_276.csv
# Saved dataset for exporter 300 to exporter_csv/dataset_for_exporter_300.csv
# Saved dataset for exporter 320 to exporter_csv/dataset_for_exporter_320.csv
# Saved dataset for exporter 344 to exporter_csv/dataset_for_exporter_344.csv
# Saved dataset for exporter 348 to exporter_csv/dataset_for_exporter_348.csv
# Saved dataset for exporter 360 to exporter_csv/dataset_for_exporter_360.csv
# Saved dataset for exporter 364 to exporter_csv/dataset_for_exporter_364.csv
# Saved dataset for exporter 368 to exporter_csv/dataset_for_exporter_368.csv
# Saved dataset for exporter 372 to exporter_csv/dataset_for_exporter_372.csv
# Saved dataset for exporter 376 to exporter_csv/dataset_for_exporter_376.csv
# Saved dataset for exporter 380 to exporter_csv/dataset_for_exporter_380.csv
# Saved dataset for exporter 388 to exporter_csv/dataset_for_exporter_388.csv
# Saved dataset for exporter 392 to exporter_csv/dataset_for_exporter_392.csv
# Saved dataset for exporter 400 to exporter_csv/dataset_for_exporter_400.csv
# Saved dataset for exporter 404 to exporter_csv/dataset_for_exporter_404.csv
# Saved dataset for exporter 410 to exporter_csv/dataset_for_exporter_410.csv
# Saved dataset for exporter 418 to exporter_csv/dataset_for_exporter_418.csv
# Saved dataset for exporter 422 to exporter_csv/dataset_for_exporter_422.csv
# Saved dataset for exporter 428 to exporter_csv/dataset_for_exporter_428.csv
# Saved dataset for exporter 434 to exporter_csv/dataset_for_exporter_434.csv
# Saved dataset for exporter 440 to exporter_csv/dataset_for_exporter_440.csv
# Saved dataset for exporter 442 to exporter_csv/dataset_for_exporter_442.csv
# Saved dataset for exporter 450 to exporter_csv/dataset_for_exporter_450.csv
# Saved dataset for exporter 466 to exporter_csv/dataset_for_exporter_466.csv
# Saved dataset for exporter 470 to exporter_csv/dataset_for_exporter_470.csv
# Saved dataset for exporter 484 to exporter_csv/dataset_for_exporter_484.csv
# Saved dataset for exporter 490 to exporter_csv/dataset_for_exporter_490.csv
# Saved dataset for exporter 504 to exporter_csv/dataset_for_exporter_504.csv
# Saved dataset for exporter 512 to exporter_csv/dataset_for_exporter_512.csv
# Saved dataset for exporter 516 to exporter_csv/dataset_for_exporter_516.csv
# Saved dataset for exporter 524 to exporter_csv/dataset_for_exporter_524.csv
# Saved dataset for exporter 528 to exporter_csv/dataset_for_exporter_528.csv
# Saved dataset for exporter 554 to exporter_csv/dataset_for_exporter_554.csv
# Saved dataset for exporter 562 to exporter_csv/dataset_for_exporter_562.csv
# Saved dataset for exporter 566 to exporter_csv/dataset_for_exporter_566.csv
# Saved dataset for exporter 579 to exporter_csv/dataset_for_exporter_579.csv
# Saved dataset for exporter 586 to exporter_csv/dataset_for_exporter_586.csv
# Saved dataset for exporter 591 to exporter_csv/dataset_for_exporter_591.csv
# Saved dataset for exporter 598 to exporter_csv/dataset_for_exporter_598.csv
# Saved dataset for exporter 604 to exporter_csv/dataset_for_exporter_604.csv
# Saved dataset for exporter 608 to exporter_csv/dataset_for_exporter_608.csv
# Saved dataset for exporter 616 to exporter_csv/dataset_for_exporter_616.csv
# Saved dataset for exporter 620 to exporter_csv/dataset_for_exporter_620.csv
# Saved dataset for exporter 642 to exporter_csv/dataset_for_exporter_642.csv
# Saved dataset for exporter 643 to exporter_csv/dataset_for_exporter_643.csv
# Saved dataset for exporter 682 to exporter_csv/dataset_for_exporter_682.csv
# Saved dataset for exporter 688 to exporter_csv/dataset_for_exporter_688.csv
# Saved dataset for exporter 694 to exporter_csv/dataset_for_exporter_694.csv
# Saved dataset for exporter 699 to exporter_csv/dataset_for_exporter_699.csv
# Saved dataset for exporter 702 to exporter_csv/dataset_for_exporter_702.csv
# Saved dataset for exporter 703 to exporter_csv/dataset_for_exporter_703.csv
# Saved dataset for exporter 704 to exporter_csv/dataset_for_exporter_704.csv
# Saved dataset for exporter 705 to exporter_csv/dataset_for_exporter_705.csv
# Saved dataset for exporter 710 to exporter_csv/dataset_for_exporter_710.csv
# Saved dataset for exporter 724 to exporter_csv/dataset_for_exporter_724.csv
# Saved dataset for exporter 740 to exporter_csv/dataset_for_exporter_740.csv
# Saved dataset for exporter 752 to exporter_csv/dataset_for_exporter_752.csv
# Saved dataset for exporter 757 to exporter_csv/dataset_for_exporter_757.csv
# Saved dataset for exporter 760 to exporter_csv/dataset_for_exporter_760.csv
# Saved dataset for exporter 762 to exporter_csv/dataset_for_exporter_762.csv
# Saved dataset for exporter 764 to exporter_csv/dataset_for_exporter_764.csv
# Saved dataset for exporter 776 to exporter_csv/dataset_for_exporter_776.csv
# Saved dataset for exporter 784 to exporter_csv/dataset_for_exporter_784.csv
# Saved dataset for exporter 788 to exporter_csv/dataset_for_exporter_788.csv
# Saved dataset for exporter 792 to exporter_csv/dataset_for_exporter_792.csv
# Saved dataset for exporter 795 to exporter_csv/dataset_for_exporter_795.csv
# Saved dataset for exporter 804 to exporter_csv/dataset_for_exporter_804.csv
# Saved dataset for exporter 818 to exporter_csv/dataset_for_exporter_818.csv
# Saved dataset for exporter 826 to exporter_csv/dataset_for_exporter_826.csv
# Saved dataset for exporter 842 to exporter_csv/dataset_for_exporter_842.csv
# Saved dataset for exporter 858 to exporter_csv/dataset_for_exporter_858.csv
# Saved dataset for exporter 860 to exporter_csv/dataset_for_exporter_860.csv
# Saved dataset for exporter 862 to exporter_csv/dataset_for_exporter_862.csv
# Saved dataset for exporter 887 to exporter_csv/dataset_for_exporter_887.csv
# Saved dataset for exporter 894 to exporter_csv/dataset_for_exporter_894.csv

# %%
# Create a dictionary to hold DataFrames for each unique `i`
datasets_by_importer = {importer: data for importer, data in filtered_data.groupby(level='j')}

# Create the output directory if it doesn't exist
output_dir_import = "import_csv"
os.makedirs(output_dir_import, exist_ok=True)  # Create the folder if it doesn't already exist

# Save each DataFrame to a CSV file
for importer, df in datasets_by_importer.items():
    output_file_import = os.path.join(output_dir_import, f"dataset_for_importer_{importer}.csv")  # Construct file path
    df.to_csv(output_file_import)  # Save to CSV
    print(f"Saved dataset for importer {importer} to {output_file_import}")
# Out:
# Saved dataset for importer 8 to importer_csv/dataset_for_importer_8.csv
# Saved dataset for importer 20 to importer_csv/dataset_for_importer_20.csv
# Saved dataset for importer 31 to importer_csv/dataset_for_importer_31.csv
# Saved dataset for importer 32 to importer_csv/dataset_for_importer_32.csv
# Saved dataset for importer 36 to importer_csv/dataset_for_importer_36.csv
# Saved dataset for importer 40 to importer_csv/dataset_for_importer_40.csv
# Saved dataset for importer 48 to importer_csv/dataset_for_importer_48.csv
# Saved dataset for importer 51 to importer_csv/dataset_for_importer_51.csv
# Saved dataset for importer 56 to importer_csv/dataset_for_importer_56.csv
# Saved dataset for importer 60 to importer_csv/dataset_for_importer_60.csv
# Saved dataset for importer 76 to importer_csv/dataset_for_importer_76.csv
# Saved dataset for importer 92 to importer_csv/dataset_for_importer_92.csv
# Saved dataset for importer 100 to importer_csv/dataset_for_importer_100.csv
# Saved dataset for importer 104 to importer_csv/dataset_for_importer_104.csv
# Saved dataset for importer 116 to importer_csv/dataset_for_importer_116.csv
# Saved dataset for importer 124 to importer_csv/dataset_for_importer_124.csv
# Saved dataset for importer 136 to importer_csv/dataset_for_importer_136.csv
# Saved dataset for importer 152 to importer_csv/dataset_for_importer_152.csv
# Saved dataset for importer 156 to importer_csv/dataset_for_importer_156.csv
# Saved dataset for importer 188 to importer_csv/dataset_for_importer_188.csv
# Saved dataset for importer 191 to importer_csv/dataset_for_importer_191.csv
# Saved dataset for importer 196 to importer_csv/dataset_for_importer_196.csv
# Saved dataset for importer 203 to importer_csv/dataset_for_importer_203.csv
# Saved dataset for importer 208 to importer_csv/dataset_for_importer_208.csv
# Saved dataset for importer 214 to importer_csv/dataset_for_importer_214.csv
# Saved dataset for importer 233 to importer_csv/dataset_for_importer_233.csv
# Saved dataset for importer 246 to importer_csv/dataset_for_importer_246.csv
# Saved dataset for importer 251 to importer_csv/dataset_for_importer_251.csv
# Saved dataset for importer 268 to importer_csv/dataset_for_importer_268.csv
# Saved dataset for importer 276 to importer_csv/dataset_for_importer_276.csv
# Saved dataset for importer 292 to importer_csv/dataset_for_importer_292.csv
# Saved dataset for importer 300 to importer_csv/dataset_for_importer_300.csv
# Saved dataset for importer 320 to importer_csv/dataset_for_importer_320.csv
# Saved dataset for importer 344 to importer_csv/dataset_for_importer_344.csv
# Saved dataset for importer 348 to importer_csv/dataset_for_importer_348.csv
# Saved dataset for importer 352 to importer_csv/dataset_for_importer_352.csv
# Saved dataset for importer 360 to importer_csv/dataset_for_importer_360.csv
# Saved dataset for importer 368 to importer_csv/dataset_for_importer_368.csv
# Saved dataset for importer 372 to importer_csv/dataset_for_importer_372.csv
# Saved dataset for importer 376 to importer_csv/dataset_for_importer_376.csv
# Saved dataset for importer 380 to importer_csv/dataset_for_importer_380.csv
# Saved dataset for importer 392 to importer_csv/dataset_for_importer_392.csv
# Saved dataset for importer 400 to importer_csv/dataset_for_importer_400.csv
# Saved dataset for importer 410 to importer_csv/dataset_for_importer_410.csv
# Saved dataset for importer 414 to importer_csv/dataset_for_importer_414.csv
# Saved dataset for importer 422 to importer_csv/dataset_for_importer_422.csv
# Saved dataset for importer 428 to importer_csv/dataset_for_importer_428.csv
# Saved dataset for importer 440 to importer_csv/dataset_for_importer_440.csv
# Saved dataset for importer 442 to importer_csv/dataset_for_importer_442.csv
# Saved dataset for importer 446 to importer_csv/dataset_for_importer_446.csv
# Saved dataset for importer 458 to importer_csv/dataset_for_importer_458.csv
# Saved dataset for importer 462 to importer_csv/dataset_for_importer_462.csv
# Saved dataset for importer 470 to importer_csv/dataset_for_importer_470.csv
# Saved dataset for importer 484 to importer_csv/dataset_for_importer_484.csv
# Saved dataset for importer 490 to importer_csv/dataset_for_importer_490.csv
# Saved dataset for importer 496 to importer_csv/dataset_for_importer_496.csv
# Saved dataset for importer 504 to importer_csv/dataset_for_importer_504.csv
# Saved dataset for importer 512 to importer_csv/dataset_for_importer_512.csv
# Saved dataset for importer 516 to importer_csv/dataset_for_importer_516.csv
# Saved dataset for importer 524 to importer_csv/dataset_for_importer_524.csv
# Saved dataset for importer 528 to importer_csv/dataset_for_importer_528.csv
# Saved dataset for importer 533 to importer_csv/dataset_for_importer_533.csv
# Saved dataset for importer 554 to importer_csv/dataset_for_importer_554.csv
# Saved dataset for importer 558 to importer_csv/dataset_for_importer_558.csv
# Saved dataset for importer 566 to importer_csv/dataset_for_importer_566.csv
# Saved dataset for importer 579 to importer_csv/dataset_for_importer_579.csv
# Saved dataset for importer 585 to importer_csv/dataset_for_importer_585.csv
# Saved dataset for importer 586 to importer_csv/dataset_for_importer_586.csv
# Saved dataset for importer 591 to importer_csv/dataset_for_importer_591.csv
# Saved dataset for importer 604 to importer_csv/dataset_for_importer_604.csv
# Saved dataset for importer 616 to importer_csv/dataset_for_importer_616.csv
# Saved dataset for importer 620 to importer_csv/dataset_for_importer_620.csv
# Saved dataset for importer 634 to importer_csv/dataset_for_importer_634.csv
# Saved dataset for importer 642 to importer_csv/dataset_for_importer_642.csv
# Saved dataset for importer 643 to importer_csv/dataset_for_importer_643.csv
# Saved dataset for importer 682 to importer_csv/dataset_for_importer_682.csv
# Saved dataset for importer 688 to importer_csv/dataset_for_importer_688.csv
# Saved dataset for importer 699 to importer_csv/dataset_for_importer_699.csv
# Saved dataset for importer 702 to importer_csv/dataset_for_importer_702.csv
# Saved dataset for importer 703 to importer_csv/dataset_for_importer_703.csv
# Saved dataset for importer 704 to importer_csv/dataset_for_importer_704.csv
# Saved dataset for importer 705 to importer_csv/dataset_for_importer_705.csv
# Saved dataset for importer 710 to importer_csv/dataset_for_importer_710.csv
# Saved dataset for importer 724 to importer_csv/dataset_for_importer_724.csv
# Saved dataset for importer 752 to importer_csv/dataset_for_importer_752.csv
# Saved dataset for importer 757 to importer_csv/dataset_for_importer_757.csv
# Saved dataset for importer 764 to importer_csv/dataset_for_importer_764.csv
# Saved dataset for importer 784 to importer_csv/dataset_for_importer_784.csv
# Saved dataset for importer 792 to importer_csv/dataset_for_importer_792.csv
# Saved dataset for importer 800 to importer_csv/dataset_for_importer_800.csv
# Saved dataset for importer 804 to importer_csv/dataset_for_importer_804.csv
# Saved dataset for importer 826 to importer_csv/dataset_for_importer_826.csv
# Saved dataset for importer 842 to importer_csv/dataset_for_importer_842.csv
# Saved dataset for importer 860 to importer_csv/dataset_for_importer_860.csv
# Saved dataset for importer 887 to importer_csv/dataset_for_importer_887.csv

# %%
unique_exporters = filtered_data.index.get_level_values('i').unique()
print(f"Index of unique exporters: {unique_exporters}")

unique_importers = filtered_data.index.get_level_values('j').unique()
print(f'Index of unique importers: {unique_importers}')
# Out:
# Index of unique exporters: Index([  4,   8,  12,  24,  31,  32,  36,  40,  48,  51,
#        ...
#        795, 804, 818, 826, 842, 858, 860, 862, 887, 894],
#       dtype='int64', name='i', length=110)
# Index of unique importers: Index([276, 372, 826, 842, 757, 251, 348, 246, 380, 528, 554,  32,  36,  56,
#        100, 124, 156, 191, 196, 203, 208, 233, 300, 344, 376, 392, 410, 440,
#        442, 490, 579, 616, 620, 642, 643, 699, 703, 705, 724, 752, 792,  40,
#        136, 152, 484, 634, 702, 764, 784, 470, 591, 116, 422, 446, 458, 586,
#        710,  20,  76, 320, 360, 414, 504, 512, 682, 704, 268, 804, 352, 516,
#        188, 368,  92, 428,   8,  31,  48,  60, 104, 292, 400, 496, 558, 585,
#        688, 800, 860, 887,  51, 214, 462, 524, 533, 566, 604],
#       dtype='int64', name='j')

# %%
# Our number of nodes / number of exporting countries: 110
print(len(unique_exporters))
print(len(unique_importers))
# Out:
# 110
# 95

# %%
# Path to the folder containing the CSV files for each exporter
path_to_csvs = "export_csv/*.csv"  # Adjust this path as needed

# Create a dictionary to store combined quantities for each importer
combined_quantities = {}

# Load each CSV file and aggregate the quantities
for file in glob.glob(path_to_csvs):
    df = pd.read_csv(file, index_col=[0, 1, 2])  # Assuming Multi-Index (t, i, j)

    # Ensure 'q' is numeric and coerce errors to NaN
    df['q'] = pd.to_numeric(df['q'], errors='coerce')

    # Group by importer (j) and sum the quantities (q)
    quantities_by_importer = df.groupby(level='j')['q'].sum()  # NA values will be ignored by default

    # Combine results
    for importer, quantity in quantities_by_importer.items():
        if pd.isna(quantity):  # Check for NaN
            quantity = 0  # Treat NaN as 0 for aggregation

        if importer in combined_quantities:
            combined_quantities[importer] += quantity
        else:
            combined_quantities[importer] = quantity

# Convert combined_quantities dictionary to DataFrame for better visualization
combined_quantities_df = pd.DataFrame.from_dict(combined_quantities, orient='index', columns=['Total Quantity'])
combined_quantities_df.reset_index(inplace=True)
combined_quantities_df.rename(columns={'index': 'Importer'}, inplace=True)

# Sort the DataFrame by the 'Importer' (country code) column
combined_quantities_df.sort_values(by='Importer', inplace=True)

# Display the combined quantities for each importer
print(combined_quantities_df)

# Save the combined quantities to a CSV file if needed
combined_quantities_df.to_csv("combined_quantities_by_importer.csv", index=False)
# Out:
#     Importer  Total Quantity
# 70         8           0.006
# 2         20           0.080
# 71        31           0.001
# 69        32           0.541
# 3         36          22.733
# ..       ...             ...
# 85       804           0.079
# 1        826         146.720
# 55       842         879.566
# 86       860           0.096
# 87       887           0.005
#
# [95 rows x 2 columns]

# %%
# Path to the folder containing the CSV files for each exporter
path_to_csvs = "export_csv/*.csv"  # Adjust this path as needed

# Initialize a directed graph
G = nx.DiGraph()

# Load each CSV file and create edges for the directed graph
for file in glob.glob(path_to_csvs):
    # Read the CSV file
    df = pd.read_csv(file, index_col=[0, 1, 2])  # Assuming Multi-Index (t, i, j)
    
    # Ensure 'q' is numeric and coerce errors to NaN
    df['q'] = pd.to_numeric(df['q'], errors='coerce')

    # Iterate over each row and add edges to the graph
    for (t, exporter, importer), group in df.groupby(level=[0, 1, 2]):
        total_quantity = group['q'].sum(skipna=True)  # Sum quantities for the current exporter-importer pair
        if pd.notna(total_quantity):  # Ensure total_quantity is not NaN
            G.add_edge(exporter, importer, weight=total_quantity)

# Optional: You can visualize or analyze the graph now
print("Nodes in the graph:", G.number_of_nodes())
print("Edges in the graph:", G.number_of_edges())

# Optional: To save the graph to a file (e.g., GML format)
#nx.write_gml(G, "export_import_graph.gml")
# Out:
# Nodes in the graph: 126
# Edges in the graph: 952

# %%
def counting_degrees_diGraph(graph):
    '''
    A function that counts the total number of in and out degrees for each key value. Returns two lists of tuples.
    
        Input:
    graph = Your nx.diGraph
    
        Output:
    out_degree_list = A list of tuples, with the first value corresponding to the degree and the second value to nodes with
    said degree in the network. e.g (0, 25) -> 25 nodes have an outdegree 0
    in_degree_list = Same as above.
    '''
    out_degree = list(graph.out_degree)
    out_degree.sort()
    in_degree = list(graph.in_degree)
    in_degree.sort()

    
    out_degree_totals = []
    out_degree_counts = {}
    out_degree_list = []
    for i in out_degree:
        out_degree_totals.append(i[1])
    for i in out_degree_totals:
        out_degree_counts[i] = out_degree_totals.count(i)
    for key in out_degree_counts:
        out_degree_list.append((key, out_degree_counts[key]))
        
        
    # ADDED CODE TO ADD 0 FREQUENCY COUNTS, UP TO HIGHEST VALUE
    out_degree_list.sort()

    min_out_degree = out_degree_list[0][0]  # Get the minimum degree value
    max_out_degree = out_degree_list[-1][0]  # Get the maximum degree value

    # Loop over the range from min to max, adding missing values with count 0
    for degree in range(min_out_degree, max_out_degree + 1):
        if degree not in out_degree_counts:
            out_degree_list.append((degree, 0))
        
        
        
    in_degree_totals = []
    in_degree_counts = {}
    in_degree_list = []
    for i in in_degree:
        in_degree_totals.append(i[1])
    for i in in_degree_totals:
        in_degree_counts[i] = in_degree_totals.count(i)
    for key in in_degree_counts:
        in_degree_list.append((key, in_degree_counts[key]))
        
        
        
    # ADDED CODE TO ADD 0 FREQUENCY COUNTS, UP TO HIGHEST VALUE
    out_degree_list.sort()

    min_in_degree = in_degree_list[0][0]  # Get the minimum degree value
    max_in_degree = in_degree_list[-1][0]  # Get the maximum degree value

    # Loop over the range from min to max, adding missing values with count 0
    for degree in range(min_in_degree, max_in_degree + 1):
        if degree not in in_degree_counts:
            in_degree_list.append((degree, 0))
    
             
    out_degree_list.sort()
    in_degree_list.sort()
        
    return out_degree_list, in_degree_list


def cumulative_degree_plot(degree_list):
    '''
    To be expanded - A simple plot function for creating a cumulative degree plot
    
        Input:
    A degree list of tuples, as created by counting_degree_diGraph()
    
        Output:
    A plt.plot created from the two values in the tuples.
    '''
    degree_index_list = []
    degree_value_list = []
    degree_cumul_list = []
    
    for i in degree_list:
        degree_index_list.append(i[0])
        degree_value_list.append(i[1])
        
    for i in range(len(degree_index_list)):
        degree_cumul_list.append(np.sum(degree_value_list[i:]))
    
    
    list1 = []
    list2 = []
    
    for i in range(len(degree_list)):
        list1.append(degree_list[i][0])
        list2.append(degree_list[i][1])
       
    plt.xscale("log")
    plt.yscale("log")
        
    return plt.plot(degree_index_list, degree_cumul_list)


def closeness_centrality(graph):
    '''
    Small function for finding the node centrality of our network. Returns a sorted list of tuples and the highest value node.
    
    Input:
        graph = A networkx graph
        
    Output:
        node_centrality_tuples = A sorted list of tuples for each of the nodes, with their degree centrality.
        maxtup = A tuple for the highest value node.
    '''
    node_centrality = nx.degree_centrality(graph)
    node_centrality_tuples = sorted(node_centrality.items())
    maxtup = (0,0)


    for i in node_centrality_tuples:
        if i[1] > maxtup[1]:
            maxtup = i
    
    return node_centrality_tuples, maxtup

def average_neighbor_degree(graph):
    '''
    Small function for finding the average degree of the neighbors to each node in the graph. Good for finding hubs.
    
    Input:
        graph = A networkx graph
        
    Output:
        avg_neighbor_degree_tuples = A sorted list of tuples for each of the nodes, with their average neighbor degree.
        maxdic = A dictionary of the highest value nodes.
        
        OPTIONAL maxtup = A tuple for the highest value node.
    '''
    
    average_neighbor_degree_dict = nx.average_neighbor_degree(graph)
    
    avg_neighbor_degree_tuples = sorted(average_neighbor_degree_dict.items())
    maxtup = (0,0)
    maxdic = {}
    
    for i in avg_neighbor_degree_tuples:
        if i[1] > maxtup[1]:
            maxtup = i
            
    for i in avg_neighbor_degree_tuples:
        if i[1] == maxtup[1]:
            maxdic[i[0]] = i[1]
            
    return avg_neighbor_degree_tuples, maxdic #, maxtup

def betweenness_centrality(graph):
    '''
    Small function for finding the betweenness centrality - 
    Betweenness centrality is a measure used in network analysis to quantify the importance of a node within a graph 
    based on the number of shortest paths that pass through it. 
    It reflects how much a node acts as a bridge or mediator in the network.
    
    Input:
        graph = A networkx graph
    
    Output:
        betw_cen_tuples = A sorted list of tuples for each of the nodes, with their betweenness centrality.
        maxtup = A tuple for the highest value node.
    
    '''
    
    betw_cen = nx.betweenness_centrality(graph)
    
    betw_cen_tuples = sorted(betw_cen.items())
    maxtup = (0,0)
    
    for i in betw_cen_tuples:
        if i[1] > maxtup[1]:
            maxtup = i
    
    return betw_cen_tuples, maxtup


def clustering_coefficient(graph):
    '''
    Small function for finding the clustering coefficient
    
    Input:
        graph = A networkx graph
        
    Output:
        clust_co_tuples = A sorted list of tuples for each of the nodes, with their clustering coefficient
        maxdic = A dictionary for the highest value nodes
        
        OPTIONAL maxtup = A tuple for the maximum value. Logically not sound, as many nodes will share clustering coefficients.
    '''
    
    clust_co = nx.clustering(graph)
    
    clust_co_tuples = sorted(clust_co.items())
    
    maxtup = (0,0)
    maxdic = {}
    
    for i in clust_co_tuples:
        if i[1] > maxtup[1]:
            maxtup = i
            
    for i in clust_co_tuples:
        if i[1] == maxtup[1]:
            maxdic[i[0]] = i[1]
            
    return clust_co_tuples, maxdic #, maxtup

def maximum_shortest_path(graph):
    '''
    As we have a weakly connected graph, we can not directly find the diameter of our graph.
    Instead we must find the longest path within any two connected nodes in the network.
    
    Input:
        graph = A networkx graph
        
    Output:
        diameter = An integer that shows the longest path between two connected nodes.
        
    '''
    diameter = max([max(j.values()) for (i,j) in nx.shortest_path_length(graph)]) # maximum distance of a list containing the shortest paths between any two nodes in the graph (computed with Dijkstra's algorithm)
    
    # If you want to understand how the code works/runs, use the following:
    #for (i, j) in nx.shortest_path_length(graph):
    #    print(f'this is i: {i}')
    #    print(f'this is j: {j.values()}')
    
    # TO BE ADDED
    # Save the i-country to understand which nodes have the longest path.
    
    return diameter

# %%
out_degree_count, in_degree_count = counting_degrees_diGraph(G)

# %%
# Cumulative degree plots (DO WE HAVE A POWER LAW? (no))

cumulative_degree_plot(in_degree_count) # Blue
cumulative_degree_plot(out_degree_count) # Orange

# %%
# Is our graph weakly connected?
nx.is_weakly_connected(G)
# Out:
# True

# %%
# We can save the different connected subnetworks as generator sets of nodes.
component_test = nx.weakly_connected_components(G)

# Our largest connected network can be found like this - Right now it returns all 126 nodes?? How come
largest_cc = max(nx.weakly_connected_components(G), key=len)
len(largest_cc)
# Out:
# 126

# %%
# Node degree centrality
node_centrality_tuple_list, max_node_centrality = closeness_centrality(G)
avg_neighbor_deg_tuple, max_avg_neighbor_deg = average_neighbor_degree(G)
between_centr_tuple, max_between_centr = betweenness_centrality(G)
clust_coe_tup, maxdic_clust = clustering_coefficient(G)
longest_path = maximum_shortest_path(G)

print(f'Our maximum node centrality is: {max_node_centrality}')
print()
print(f'Our maximum average neighbor degree nodes are: {list(max_avg_neighbor_deg.keys())} and they have value {list(max_avg_neighbor_deg.values())[0]}')
print()
print(f'Our maximum betweenness centrality node is: {max_between_centr}')
print()
print(f'Our maximum clustering coefficient nodes are: {list(maxdic_clust.keys())} and they have value {list(maxdic_clust.values())[0]}')
print()
print(f'Our longest path in the network is: {longest_path}')
# Out:
# Our maximum node centrality is: (826, 1.1280000000000001)
#
# Our maximum average neighbor degree nodes are: [48, 466, 516, 682, 740, 762, 804] and they have value 78.0
#
# Our maximum betweenness centrality node is: (826, 0.23241688323755533)
#
# Our maximum clustering coefficient nodes are: [8, 31, 32, 51, 60, 68, 100, 116, 136, 144, 180, 188, 214, 231, 233, 268, 352, 400, 422, 434, 440, 504, 524, 608, 642, 682, 688, 705, 760, 795, 804, 858, 860, 887] and they have value 1.0
#
# Our longest path in the network is: 4

# %%
list(max_avg_neighbor_deg.values())[0]
# Out:
# 78.0

# %%
# average_degree_connectivity - Measures the average degree of nodes that have a specific degree

nx.average_degree_connectivity(G)
# Out:
# {2: 72.46428571428571,
#  76: 16.986842105263158,
#  5: 36.56666666666667,
#  141: 11.645390070921986,
#  89: 17.865168539325843,
#  1: 72.53571428571429,
#  40: 16.05,
#  60: 24.641666666666666,
#  48: 26.760416666666668,
#  14: 30.785714285714285,
#  10: 30.88,
#  52: 20.76923076923077,
#  54: 24.25925925925926,
#  8: 27.875,
#  13: 39.26373626373626,
#  31: 25.50537634408602,
#  26: 31.76923076923077,
#  15: 30.08,
#  84: 18.357142857142858,
#  16: 41.375,
#  3: 67.15384615384616,
#  39: 25.076923076923077,
#  32: 21.25,
#  30: 28.5,
#  7: 23.952380952380953,
#  6: 58.666666666666664,
#  11: 28.863636363636363,
#  82: 18.597560975609756,
#  27: 32.51851851851852,
#  23: 12.956521739130435,
#  41: 27.24390243902439,
#  21: 38.42857142857143,
#  139: 10.877697841726619,
#  17: 38.294117647058826,
#  4: 52.75,
#  24: 33.0}

# %%
# Clustering codes: https://networkx.org/documentation/stable/reference/algorithms/clustering.html

nx.transitivity(G)
# Out:
# 0.3097573379831444

# %%
# Creating a list of our country nodes 126 long

country_code_list = []

for i in G:
    country_code_list.append(i)
    
country_code_list.sort()
print(country_code_list)
# Out:
# [4, 8, 12, 20, 24, 31, 32, 36, 40, 48, 51, 56, 60, 68, 76, 92, 100, 104, 116, 120, 124, 136, 144, 152, 156, 170, 180, 188, 191, 196, 203, 208, 214, 231, 233, 246, 251, 258, 268, 276, 292, 300, 320, 344, 348, 352, 360, 364, 368, 372, 376, 380, 388, 392, 400, 404, 410, 414, 418, 422, 428, 434, 440, 442, 446, 450, 458, 462, 466, 470, 484, 490, 496, 504, 512, 516, 524, 528, 533, 554, 558, 562, 566, 579, 585, 586, 591, 598, 604, 608, 616, 620, 634, 642, 643, 682, 688, 694, 699, 702, 703, 704, 705, 710, 724, 740, 752, 757, 760, 762, 764, 776, 784, 788, 792, 795, 800, 804, 818, 826, 842, 858, 860, 862, 887, 894]

# %%
# THINGS WE SHOULD FIND:
# Degree distribution (DONE!)
# Average path length - Diameter
# Closeness Centrality
# Clustering Coefficient

# %% [markdown]
# ## Summing up our findings so far:
#
# Out of the 126 countries participating in the trade in historical artifacts in 2022, only 95 of them are importers of these same products.
#
# There are 952 connections between these countries.

# %%
# Accessing our dictionary values. We should perhaps clean up edges below a certain weight

for n, nbrsdict in G.adjacency():
    print(f'Now we are in node {n}')
    for nbr, eattr in nbrsdict.items():
        #print(eattr.items())
        temp = [v for k, v in eattr.items() if v > 0.1]
        if temp:
            temp.append(n)
        print(nbrsdict.values())
# Out:
# Now we are in node 8
# dict_values([{'weight': 0.013}])
# Now we are in node 757
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# dict_values([{'weight': 0.004}, {'weight': 0.56}, {'weight': 0.825}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.1}, {'weight': 0.08}, {'weight': 0.002}, {'weight': 0.008}, {'weight': 1.537}, {'weight': 2.257}, {'weight': 0.147}, {'weight': 0.002}, {'weight': 0.306}, {'weight': 0.0}, {'weight': 0.808}, {'weight': 0.014}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.001}, {'weight': 0.043}, {'weight': 0.03}, {'weight': 0.001}, {'weight': 0.065}, {'weight': 0.0}, {'weight': 0.139}, {'weight': 0.015}, {'weight': 1.29}, {'weight': 2.203}])
# Now we are in node 682
# dict_values([{'weight': 0.074}])
# Now we are in node 826
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# dict_values([{'weight': 0.006}, {'weight': 0.001}, {'weight': 0.291}, {'weight': 6.963}, {'weight': 1.272}, {'weight': 0.861}, {'weight': 3.723}, {'weight': 0.003}, {'weight': 0.003}, {'weight': 0.01}, {'weight': 0.017}, {'weight': 2.672}, {'weight': 0.006}, {'weight': 0.253}, {'weight': 0.735}, {'weight': 0.019}, {'weight': 0.008}, {'weight': 0.325}, {'weight': 0.478}, {'weight': 0.003}, {'weight': 0.102}, {'weight': 10.195}, {'weight': 0.002}, {'weight': 3.185}, {'weight': 0.028}, {'weight': 0.114}, {'weight': 5.583}, {'weight': 0.01}, {'weight': 0.001}, {'weight': 0.809}, {'weight': 0.076}, {'weight': 2.723}, {'weight': 3.461}, {'weight': 0.001}, {'weight': 0.202}, {'weight': 0.246}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.006}, {'weight': 0.025}, {'weight': 0.171}, {'weight': 0.56}, {'weight': 0.241}, {'weight': 0.928}, {'weight': 0.002}, {'weight': 0.002}, {'weight': 0.005}, {'weight': 0.001}, {'weight': 8.58}, {'weight': 0.71}, {'weight': 0.002}, {'weight': 0.154}, {'weight': 0.002}, {'weight': 0.007}, {'weight': 0.173}, {'weight': 0.263}, {'weight': 0.247}, {'weight': 0.028}, {'weight': 0.11}, {'weight': 0.611}, {'weight': 0.001}, {'weight': 0.304}, {'weight': 1.852}, {'weight': 0.065}, {'weight': 0.028}, {'weight': 0.014}, {'weight': 5.795}, {'weight': 1.16}, {'weight': 0.864}, {'weight': 1.352}, {'weight': 8.572}, {'weight': 1.902}, {'weight': 0.114}, {'weight': 0.005}, {'weight': 0.005}, {'weight': 128.558}, {'weight': 0.029}, {'weight': 0.005}])
# ...
# Now we are in node 434
# dict_values([{'weight': 0.0}, {'weight': 0.001}, {'weight': 0.001}])
# dict_values([{'weight': 0.0}, {'weight': 0.001}, {'weight': 0.001}])
# dict_values([{'weight': 0.0}, {'weight': 0.001}, {'weight': 0.001}])
# Now we are in node 144
# dict_values([{'weight': 0.003}, {'weight': 1.359}])
# dict_values([{'weight': 0.003}, {'weight': 1.359}])
# Now we are in node 795
# dict_values([{'weight': 0.005}, {'weight': 0.001}, {'weight': 0.024}])
# dict_values([{'weight': 0.005}, {'weight': 0.001}, {'weight': 0.024}])
# dict_values([{'weight': 0.005}, {'weight': 0.001}, {'weight': 0.024}])
# Now we are in node 51
# dict_values([{'weight': 0.009}, {'weight': 0.001}])
# dict_values([{'weight': 0.009}, {'weight': 0.001}])
# Now we are in node 92
# Now we are in node 428
# dict_values([{'weight': 0.0}, {'weight': 0.017}])
# dict_values([{'weight': 0.0}, {'weight': 0.017}])
# Now we are in node 804
# dict_values([{'weight': 0.001}])
# Now we are in node 710
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.004}, {'weight': 0.006}, {'weight': 0.113}, {'weight': 0.08}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.004}, {'weight': 0.006}, {'weight': 0.113}, {'weight': 0.08}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.004}, {'weight': 0.006}, {'weight': 0.113}, {'weight': 0.08}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.004}, {'weight': 0.006}, {'weight': 0.113}, {'weight': 0.08}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.004}, {'weight': 0.006}, {'weight': 0.113}, {'weight': 0.08}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.004}, {'weight': 0.006}, {'weight': 0.113}, {'weight': 0.08}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.004}, {'weight': 0.006}, {'weight': 0.113}, {'weight': 0.08}])
# Now we are in node 231
# dict_values([{'weight': 0.0}, {'weight': 0.246}])
# dict_values([{'weight': 0.0}, {'weight': 0.246}])
# Now we are in node 740
# dict_values([{'weight': 0.003}])
# Now we are in node 352
# Now we are in node 152
# dict_values([{'weight': 0.0}, {'weight': 0.072}, {'weight': 1.394}])
# dict_values([{'weight': 0.0}, {'weight': 0.072}, {'weight': 1.394}])
# dict_values([{'weight': 0.0}, {'weight': 0.072}, {'weight': 1.394}])
# Now we are in node 608
# dict_values([{'weight': 0.001}, {'weight': 0.002}])
# dict_values([{'weight': 0.001}, {'weight': 0.002}])
# Now we are in node 116
# dict_values([{'weight': 0.0}, {'weight': 0.022}])
# dict_values([{'weight': 0.0}, {'weight': 0.022}])
# Now we are in node 586
# dict_values([{'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.016}])
# dict_values([{'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.016}])
# dict_values([{'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.016}])
# dict_values([{'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.016}])
# dict_values([{'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.0}, {'weight': 0.016}])
# Now we are in node 591
# dict_values([{'weight': 0.01}])
# Now we are in node 136
# Now we are in node 699
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.005}, {'weight': 0.0}, {'weight': 0.006}, {'weight': 0.0}, {'weight': 0.002}, {'weight': 0.004}, {'weight': 0.053}, {'weight': 4.645}, {'weight': 0.004}, {'weight': 0.003}, {'weight': 0.09}, {'weight': 0.55}, {'weight': 43.093}])
# Now we are in node 180
# dict_values([{'weight': 0.003}, {'weight': 0.061}])
# dict_values([{'weight': 0.003}, {'weight': 0.061}])
# Now we are in node 68
# dict_values([{'weight': 0.002}, {'weight': 0.005}])
# dict_values([{'weight': 0.002}, {'weight': 0.005}])
# Now we are in node 418
# dict_values([{'weight': 0.0}])
# Now we are in node 818
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# dict_values([{'weight': 0.0}, {'weight': 0.046}, {'weight': 0.082}, {'weight': 0.023}, {'weight': 0.03}, {'weight': 0.006}, {'weight': 0.002}, {'weight': 0.081}, {'weight': 0.047}, {'weight': 0.168}, {'weight': 0.001}, {'weight': 0.198}, {'weight': 74.46}])
# Now we are in node 788
# dict_values([{'weight': 0.002}])
# Now we are in node 762
# dict_values([{'weight': 0.024}])
# Now we are in node 776
# dict_values([{'weight': 0.002}])
# Now we are in node 170
# dict_values([{'weight': 0.135}])
# Now we are in node 400
# dict_values([{'weight': 0.02}])
# Now we are in node 364
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.059}, {'weight': 0.013}, {'weight': 0.001}, {'weight': 0.008}, {'weight': 0.142}, {'weight': 0.592}, {'weight': 0.039}])
# Now we are in node 760
# dict_values([{'weight': 0.135}, {'weight': 0.932}])
# dict_values([{'weight': 0.135}, {'weight': 0.932}])
# Now we are in node 562
# dict_values([{'weight': 1.406}])
# Now we are in node 48
# dict_values([{'weight': 0.001}])
# Now we are in node 60
# Now we are in node 104
# dict_values([{'weight': 0.066}, {'weight': 0.004}])
# dict_values([{'weight': 0.066}, {'weight': 0.004}])
# Now we are in node 292
# Now we are in node 496
# Now we are in node 516
# dict_values([{'weight': 0.001}])
# Now we are in node 558
# Now we are in node 585
# Now we are in node 688
# dict_values([{'weight': 0.0}, {'weight': 0.002}, {'weight': 0.003}])
# dict_values([{'weight': 0.0}, {'weight': 0.002}, {'weight': 0.003}])
# dict_values([{'weight': 0.0}, {'weight': 0.002}, {'weight': 0.003}])
# Now we are in node 800
# Now we are in node 887
# dict_values([{'weight': 0.025}, {'weight': 0.178}])
# dict_values([{'weight': 0.025}, {'weight': 0.178}])
# Now we are in node 598
# dict_values([{'weight': 0.025}])
# Now we are in node 214
# dict_values([{'weight': 0.001}])
# Now we are in node 566
# dict_values([{'weight': 0.048}])
# Now we are in node 604
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.058}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.058}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.058}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.058}])
# dict_values([{'weight': 0.0}, {'weight': 0.0}, {'weight': 0.001}, {'weight': 0.002}, {'weight': 0.058}])
# Now we are in node 404
# dict_values([{'weight': 0.004}])
# Now we are in node 388
# dict_values([{'weight': 0.006}])
# Now we are in node 258
# dict_values([{'weight': 0.007}])
# Now we are in node 12
# dict_values([{'weight': 0.004}])
# Now we are in node 4
# dict_values([{'weight': 0.003}, {'weight': 0.015}, {'weight': 0.034}, {'weight': 0.002}])
# dict_values([{'weight': 0.003}, {'weight': 0.015}, {'weight': 0.034}, {'weight': 0.002}])
# dict_values([{'weight': 0.003}, {'weight': 0.015}, {'weight': 0.034}, {'weight': 0.002}])
# dict_values([{'weight': 0.003}, {'weight': 0.015}, {'weight': 0.034}, {'weight': 0.002}])
# Now we are in node 462
# Now we are in node 533
# Now we are in node 894
# dict_values([{'weight': 0.5}])
# Now we are in node 466
# dict_values([{'weight': 0.001}])

# %%
# Draw the graph (this may not work well for very large graphs)
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G)  # positions for all nodes
nx.draw_networkx_nodes(G, pos, node_size=700)
nx.draw_networkx_edges(G, pos, arrowstyle='-|>', arrowsize=20)
nx.draw_networkx_labels(G, pos, font_size=10)
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

plt.title("Imports/Exports Directed Graph")
plt.show()
